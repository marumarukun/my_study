# %%
import requests

# %%
URL = 'https://app.rakuten.co.jp/services/api/Travel/KeywordHotelSearch/20170426'
APP_ID = '1020946659829102563'

# %%
params = {
    'applicationId': APP_ID,
    'format': 'json',
    'keyword': '沖縄'
}

# %%
res = requests.get(URL, params=params)

# %%
res.status_code
# Out:
# 200

# %%
hotels = res.json()['hotels']
hotels
# Out:
# [{'hotel': [{'hotelBasicInfo': {'hotelNo': 30045,
#      'hotelName': 'グランドメルキュール沖縄残波岬リゾート（旧ロイヤルホテル沖縄残波岬）',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=30045',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=30045&f_flg=PLAN',
#      'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=30045',
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=30045',
#      'hotelKanaName': 'ぐらんどめるきゅーるおきなわざんぱみさきりぞーと',
#      'hotelSpecial': '24年8月県内最大級のプールOPEN。全客室にお酒やソフトドリンク、軽食が楽しめるラウンジアクセス付',
#      'hotelMinCharge': None,
#      'latitude': 95153.13,
#      'longitude': 459791.38,
#      'postalCode': '904-0394',
#      'address1': '沖縄県',
#      'address2': '中頭郡読谷村字宇座1575',
#      'telephoneNo': '098-958-5000',
#      'faxNo': '098-958-3970',
#      'access': '那覇空港より国道５８号線を名護方面へ読谷村伊良皆交差点を残波岬方面へ。車で70分。',
#      'parkingInformation': '有(無料）',
#      'nearestStation': '那覇空港',
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/30045/30045.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/30045.jpg',
#      'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/30045/30045_s.jpg',
#      'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/30045.jpg',
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/30045/30045map.gif',
#      'reviewCount': 967,
#      'reviewAverage': 4.09,
#      'userReview': '工事中と修学旅行生が一緒だったので、少し騒がしく感じました。ウエルカムビールがとても助かりました。朝食ビュフェも、品数がとても多く、景観の良いところで、とても満足しました。ミニハンバーガー…\u30002023-12-25 16:31:04投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=30045" class="3click">つづきはこちら</a>'}},
#    {'hotelRatingInfo': {'serviceAverage': 4,
#      'locationAverage': 4.16,
#      'roomAverage': 3.79,
#      'equipmentAverage': 3.88,
#      'bathAverage': 4.37,
#      'mealAverage': 3.9}}]},
#  {'hotel': [{'hotelBasicInfo': {'hotelNo': 76401,
#      'hotelName': 'サザンビーチホテル&リゾート沖縄',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=76401',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=76401&f_flg=PLAN',
#      'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=76401',
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=76401',
#      'hotelKanaName': 'さざんびーちほてるあんどりぞーとおきなわ',
#      'hotelSpecial': '空港から約20分、沖縄本島南部のビーチリゾート 空港－南部観光地－ホテル間を結ぶ路線バス運行中',
#      'hotelMinCharge': 6020,
#      'latitude': 94059.03,
#      'longitude': 459558.15,
#      'postalCode': '901-0306',
#      'address1': '沖縄県',
#      'address2': '糸満市西崎町1-6-1',
#      'telephoneNo': '098-992-7500',
#      'faxNo': '098-992-7600',
#      'access': '空港より車で約20分／東京バス「ウミカジライナー」で空港から約45分・国際通りからも乗り換え不要',
#      'parkingInformation': '有り\u3000510台\u3000予約不要\u3000宿泊者550円\u3000レストラン利用2時間無料\u3000宴会利用3時間無料\u3000',
#      'nearestStation': '那覇空港',
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/76401/76401.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/76401.jpg',
#      'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/76401/76401_ky1.jpg',
#      'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/76401.jpg',
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/76401/76401map.gif',
#      'reviewCount': 1292,
#      'reviewAverage': 4.23,
#      'userReview': '朝食のサーモンが美味しいです。\u30002024-02-23 07:02:43投稿'}},
#    {'hotelRatingInfo': {'serviceAverage': 4.16,
#      'locationAverage': 4.09,
#      'roomAverage': 4.1,
#      'equipmentAverage': 3.98,
#      'bathAverage': 3.72,
#      'mealAverage': 4.24}}]},
#  {'hotel': [{'hotelBasicInfo': {'hotelNo': 72075,
#      'hotelName': 'クラウンホテル沖縄',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=72075',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=72075&f_flg=PLAN',
#      'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=72075',
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=72075',
#      'hotelKanaName': 'くらうんほてるおきなわ',
#      'hotelSpecial': '沖縄市中心街！沖縄南IC近く！サウナあり◎大浴場あり◎まったり過ごす休日に！',
#      'hotelMinCharge': 3680,
#      'latitude': 94797.79,
#      'longitude': 460071.99,
#      'postalCode': '904-0031',
#      'address1': '沖縄県',
#      'address2': '沖縄市上地4-1-51',
#      'telephoneNo': '098-933-2551',
#      'faxNo': '098-932-2194',
#      'access': '那覇空港より車で約40分、高速バスからのアクセスも便利♪［マップコード: 33 590 831*41］',
#      'parkingInformation': '【無料\u3000敷地内20台＋指定駐車場15台\u3000予約不要※1室につき1台無料。追加1台 1,000円/日】',
#      'nearestStation': '那覇空港',
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/72075/72075.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/72075.jpg',
#      'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/72075/72075_room.jpg',
#      'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/72075.jpg',
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/72075/72075map.gif',
#      'reviewCount': 162,
#      'reviewAverage': 4.38,
#      'userReview': None}},
#    {'hotelRatingInfo': {'serviceAverage': 0,
#      'locationAverage': 0,
#      'roomAverage': 0,
#      'equipmentAverage': 0,
#      'bathAverage': 0,
#      'mealAverage': 0}}]},
#  {'hotel': [{'hotelBasicInfo': {'hotelNo': 187433,
#      'hotelName': 'レフ沖縄アリーナｂｙベッセルホテルズ｜ＲＥＦ沖縄アリーナ｜プール＆ＢＡＲ（２０２３年８月１日開業）',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=187433',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=187433&f_flg=PLAN',
#      'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=187433',
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=187433',
#      'hotelKanaName': 'れふおきなわありーなｂｙべっせるほてるず｜ＲＥＦおきなわありーな｜ぷーる＆\u3000ＢＡＲ',
#      'hotelSpecial': '2023年8月新規オープン\u3000沖縄アリーナ徒歩２分\u3000コザ運動公園目前\u3000サウナ付大浴場\u3000敷地内コンビニ有',
#      'hotelMinCharge': 3633,
#      'latitude': 94789.01,
#      'longitude': 460040.41,
#      'postalCode': '904-0032',
#      'address1': '沖縄県',
#      'address2': '沖縄市字諸見里1766',
#      'telephoneNo': '098-933-6111',
#      'faxNo': '098-933-6112',
#      'access': '那覇空港より高速バスで約60分\u3000南ICより車で2分の好立地！',
#      'parkingInformation': '約150台（無料駐車場）',
#      'nearestStation': '那覇空港',
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/187433/187433.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/187433.jpg',
#      'roomImageUrl': None,
#      'roomThumbnailUrl': None,
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/187433/187433map.gif',
#      'reviewCount': 32,
#      'reviewAverage': 4.5,
#      'userReview': '子連れのためデラックスルームに宿泊しました!ちゃぶ台のようなテーブルと椅子、とてもセンスが良かったです。お風呂も、サウナが2種類あり、充実していました。それと、浴室のドライヤーがダイソンなのが…\u30002024-02-22 21:37:04投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=187433" class="3click">つづきはこちら</a>'}},
#    {'hotelRatingInfo': {'serviceAverage': 4.22,
#      'locationAverage': 4.42,
#      'roomAverage': 4.38,
#      'equipmentAverage': 4.38,
#      'bathAverage': 4.4,
#      'mealAverage': 4.38}}]},
#  {'hotel': [{'hotelBasicInfo': {'hotelNo': 106002,
#      'hotelName': 'ベストウェスタン沖縄幸喜ビーチ',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=106002',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=106002&f_flg=PLAN',
#      'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=106002',
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=106002',
#      'hotelKanaName': 'べすとうぇすたん おきなわこうきびーち',
#      'hotelSpecial': 'レストランやお部屋からはエメラルドブルーの海！白砂のロングビーチまで約１０m、併設施設にコンビニ有',
#      'hotelMinCharge': 6820,
#      'latitude': 95527.19,
#      'longitude': 460622.63,
#      'postalCode': '905-0025',
#      'address1': '沖縄県',
#      'address2': '名護市幸喜117',
#      'telephoneNo': '0980-54-8155',
#      'faxNo': '0980-54-8152',
#      'access': '那覇空港からから沖縄自動車道(豊見城・名嘉地IC～許田IC)を利用時、約７０分。',
#      'parkingInformation': '有（４０台）／無料',
#      'nearestStation': '那覇空港',
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/106002/106002.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/106002.jpg',
#      'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/106002/106002_de.jpg',
#      'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/106002.jpg',
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/106002/106002map.gif',
#      'reviewCount': 578,
#      'reviewAverage': 4.43,
#      'userReview': '阪神キャンプ地から近いホテルで利用しました！全てにおいて完璧なホテルでした。夕食バイキングでは最後の時間帯にも関わらず、残り少なくなってきた物をきちんと補充していただき、何一つ嫌な顔をせずに、さすが接…\u30002024-02-24 23:20:44投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=106002" class="3click">つづきはこちら</a>'}},
#    {'hotelRatingInfo': {'serviceAverage': 4.17,
#      'locationAverage': 4.63,
#      'roomAverage': 4.47,
#      'equipmentAverage': 3.92,
#      'bathAverage': 4.14,
#      'mealAverage': 4.03}}]},
#  {'hotel': [{'hotelBasicInfo': {'hotelNo': 29924,
#      'hotelName': 'ホテル\u3000グランビュー沖縄',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=29924',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=29924&f_flg=PLAN',
#      'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=29924',
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=29924',
#      'hotelKanaName': 'ぐらんびゅー\u3000おきなわ',
#      'hotelSpecial': '那覇空港からモノレールで1駅、赤嶺駅隣接\u3000ビジネスラクジュアリーへようこそ 朝食5:45オープン',
#      'hotelMinCharge': 3500,
#      'latitude': 94280.18,
#      'longitude': 459583.25,
#      'postalCode': '901-0154',
#      'address1': '沖縄県',
#      'address2': '那覇市赤嶺2-3-2',
#      'telephoneNo': '098-859-4890',
#      'faxNo': '098-859-4891',
#      'access': '那覇空港より沖縄都市モノレ－ルで約4分\u3000赤嶺駅下車徒歩１分',
#      'parkingInformation': '有\u3000１８台\u3000１０００円（税別／泊）\u3000先着順  第2駐車場あり\u30009台',
#      'nearestStation': '那覇空港',
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/29924/29924.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/29924.jpg',
#      'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/29924/29924_t.jpg',
#      'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/29924.jpg',
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/29924/29924map.gif',
#      'reviewCount': 2889,
#      'reviewAverage': 4.32,
#      'userReview': '那覇空港近くのホテルをGoogle検索で見つけ、今回初めて利用。立地やフロントのサービスなど素晴らしく、また利用したい！特に朝食は早朝5:45から対応されていて、味も美味しかったです。道路向か…\u30002024-02-24 15:40:57投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=29924" class="3click">つづきはこちら</a>'}},
#    {'hotelRatingInfo': {'serviceAverage': 4,
#      'locationAverage': 4.8,
#      'roomAverage': 4.05,
#      'equipmentAverage': 3.86,
#      'bathAverage': 3.82,
#      'mealAverage': 4.22}}]},
#  {'hotel': [{'hotelBasicInfo': {'hotelNo': 145475,
#      'hotelName': 'ヒルトン沖縄北谷リゾート',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=145475',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=145475&f_flg=PLAN',
#      'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=145475',
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=145475',
#      'hotelKanaName': 'ひるとんおきなわちゃたんりぞーと',
#      'hotelSpecial': '空港から車で約40分のリゾート★県内最大級プールやスパ等充実の施設＆ビーチやショッピングも徒歩圏内♪',
#      'hotelMinCharge': 12943,
#      'latitude': 94731.93,
#      'longitude': 459923.35,
#      'postalCode': '904-0115',
#      'address1': '沖縄県',
#      'address2': '中頭郡北谷町美浜40-1',
#      'telephoneNo': '098-901-1111',
#      'faxNo': '098-901-1100',
#      'access': '那覇空港よりお車で約40分\u3000北谷エアポートエクスプレスで約45分',
#      'parkingInformation': '有り\u3000約200台\u3000（無料）\u3000予約不要',
#      'nearestStation': '那覇空港',
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/145475/145475.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/145475.jpg',
#      'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/145475/145475_room.jpg',
#      'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/145475.jpg',
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/145475/145475map.gif',
#      'reviewCount': 174,
#      'reviewAverage': 4.35,
#      'userReview': '2月に宿泊しました。沖縄ではオフピークシーズンですが、それなりに宿泊の方が多く、さすがヒルトングループだと思いました。\u30002024-02-13 16:18:46投稿'}},
#    {'hotelRatingInfo': {'serviceAverage': 4.29,
#      'locationAverage': 4.82,
#      'roomAverage': 4.29,
#      'equipmentAverage': 4.41,
#      'bathAverage': 4,
#      'mealAverage': 3.94}}]},
#  {'hotel': [{'hotelBasicInfo': {'hotelNo': 184118,
#      'hotelName': 'ウォーターマークホテル&リゾーツ沖縄\u3000宮古島＜伊良部島＞',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=184118',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=184118&f_flg=PLAN',
#      'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=184118',
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=184118',
#      'hotelKanaName': 'うぉーたーまーくほてるあんどりぞーつおきなわ\u3000みやこじま',
#      'hotelSpecial': '日本の渚100選に選ばれた美しいビーチで、夕陽の名所ホテルより青い海も、夕陽も一望できます。',
#      'hotelMinCharge': 4680,
#      'latitude': 89399.24,
#      'longitude': 450574.68,
#      'postalCode': '906-0507',
#      'address1': '沖縄県',
#      'address2': '宮古島市伊良部佐和田前原1725',
#      'telephoneNo': '0980-78-5100',
#      'faxNo': '0980-78-5101',
#      'access': '宮古島空港より車で約35分、みやこ下地島空港より車で約5分',
#      'parkingInformation': '有り\u300050台\u30001室につき1台無料\u3000（予約不要）',
#      'nearestStation': '宮古空港',
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/184118/184118.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/184118.jpg',
#      'roomImageUrl': None,
#      'roomThumbnailUrl': None,
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/184118/184118map.gif',
#      'reviewCount': 59,
#      'reviewAverage': 4.45,
#      'userReview': '2/22から1泊宿泊させていただきました。お部屋に入ると、目の前が宮古ブルーで見晴らしも良く、気持ちがとても良かったです。おふろは、部屋からガラス張りになってましたが、ロールカーテンで見えないよう…\u30002024-02-24 10:27:27投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=184118" class="3click">つづきはこちら</a>'}},
#    {'hotelRatingInfo': {'serviceAverage': 4.29,
#      'locationAverage': 4.61,
#      'roomAverage': 4.71,
#      'equipmentAverage': 4.19,
#      'bathAverage': 4.36,
#      'mealAverage': 4.04}}]},
#  {'hotel': [{'hotelBasicInfo': {'hotelNo': 177761,
#      'hotelName': '東急ステイ沖縄那覇',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=177761',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=177761&f_flg=PLAN',
#      'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=177761',
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=177761',
#      'hotelKanaName': 'とうきゅうすてい\u3000おきなわ\u3000なは',
#      'hotelSpecial': '食事評価4.2★沖縄料理が満載♪空港からゆいレールで4駅の好立地、全室洗濯乾燥機&ミニキッチン完備！',
#      'hotelMinCharge': 6475,
#      'latitude': 94334.89,
#      'longitude': 459646.32,
#      'postalCode': '900-0025',
#      'address1': '沖縄県',
#      'address2': '那覇市壷川3-2-1',
#      'telephoneNo': '098-833-1090',
#      'faxNo': '098-833-1091',
#      'access': '沖縄都市モノレール線\u3000壷川駅より徒歩にて約３分',
#      'parkingInformation': '屋内提携駐車場\u3000出入不可：1,500円（消費税込）',
#      'nearestStation': None,
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/177761/177761.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/177761.jpg',
#      'roomImageUrl': None,
#      'roomThumbnailUrl': None,
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/177761/177761map.gif',
#      'reviewCount': 578,
#      'reviewAverage': 4.51,
#      'userReview': '那覇に出張の際は、いつも利用させてもらってます。洗濯機あるのが素晴らしいです。\u30002024-01-31 15:39:59投稿'}},
#    {'hotelRatingInfo': {'serviceAverage': 4.2,
#      'locationAverage': 4.44,
#      'roomAverage': 4.49,
#      'equipmentAverage': 4.31,
#      'bathAverage': 3.89,
#      'mealAverage': 4.4}}]},
#  {'hotel': [{'hotelBasicInfo': {'hotelNo': 180687,
#      'hotelName': 'ＨＩＹＯＲＩオーシャンリゾート沖縄',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=180687',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=180687&f_flg=PLAN',
#      'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=180687',
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=180687',
#      'hotelKanaName': 'ひより\u3000おーしゃんりぞーと\u3000おきなわ',
#      'hotelSpecial': '全室オーシャンビュー。上質な滞在型ラグジュアリーリゾート。美ら海を夕陽がオレンジ色に染める絶景',
#      'hotelMinCharge': 8820,
#      'latitude': 95176.66,
#      'longitude': 460106.12,
#      'postalCode': '904-0415',
#      'address1': '沖縄県',
#      'address2': '国頭郡恩納村仲泊1055-1',
#      'telephoneNo': '098-965-1600',
#      'faxNo': '098-965-1601',
#      'access': '那覇空港から沖縄自動車道利用にて車で４９分（那覇ＩＣ～石川ＩＣから西側へ５分）または那覇空港から国道５８号線にて約６５分',
#      'parkingInformation': '204台の駐車場をご用意（1泊１台1,100円予約不要）B1の一部、B2、B3は屋根付でございます',
#      'nearestStation': '那覇空港',
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/180687/180687.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/180687.jpg',
#      'roomImageUrl': None,
#      'roomThumbnailUrl': None,
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/180687/180687map.gif',
#      'reviewCount': 182,
#      'reviewAverage': 4.85,
#      'userReview': '部屋がとても広くて、オシャレで綺麗でした！\u3000冷蔵庫にアイスやドリンクもいれてくださっていて、見つけた時はテンションがあがらりました!\u3000大浴場にタオルも置いてあるので、部屋から持っていく必要もなく、本当…\u30002024-02-24 16:18:35投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=180687" class="3click">つづきはこちら</a>'}},
#    {'hotelRatingInfo': {'serviceAverage': 4.82,
#      'locationAverage': 4.38,
#      'roomAverage': 4.96,
#      'equipmentAverage': 4.88,
#      'bathAverage': 4.64,
#      'mealAverage': 4.83}}]},
#  {'hotel': [{'hotelBasicInfo': {'hotelNo': 178706,
#      'hotelName': '北谷温泉\u3000レクー沖縄北谷スパ＆リゾート｜ＬｅＱｕ\u3000沖縄北谷｜ベッセルホテルズ',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=178706',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=178706&f_flg=PLAN',
#      'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=178706',
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=178706',
#      'hotelKanaName': 'ちゃたんおんせんれくーおきなわちゃたんすぱあんどりぞーと',
#      'hotelSpecial': '2020年開業\u3000天然北谷温泉やバリエーションに富んだ客室を保有するベッセルグループ初のリゾートホテル',
#      'hotelMinCharge': 5000,
#      'latitude': 94727.78,
#      'longitude': 459924.56,
#      'postalCode': '904-0115',
#      'address1': '沖縄県',
#      'address2': '中頭郡北谷町美浜34-2',
#      'telephoneNo': '098-936-2288',
#      'faxNo': '098-936-7788',
#      'access': '那覇空港より車で約４０分、沖縄アリーナより車で15分、北谷アメリカンビレッジとサンセットビーチまで徒歩５分以内',
#      'parkingInformation': '北谷アメリカンビレッジ近くのホテルに隣接の自走式立体駐車場無料\u3000250台収容可能！',
#      'nearestStation': '那覇空港',
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/178706/178706.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/178706.jpg',
#      'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/178706/178706_kan1.jpg',
#      'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/178706.jpg',
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/178706/178706map.gif',
#      'reviewCount': 522,
#      'reviewAverage': 4.65,
#      'userReview': 'お部屋が綺麗で最高！！立地も良いです。欲を言えば、ベッセルカンパーナのように、マッサージ機があれば嬉しい。\u30002024-02-23 15:59:24投稿'}},
#    {'hotelRatingInfo': {'serviceAverage': 4.54,
#      'locationAverage': 4.8,
#      'roomAverage': 4.6,
#      'equipmentAverage': 4.45,
#      'bathAverage': 4.56,
#      'mealAverage': 4.66}}]},
#  {'hotel': [{'hotelBasicInfo': {'hotelNo': 107650,
#      'hotelName': 'ベストウェスタン沖縄恩納ビーチ',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=107650',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=107650&f_flg=PLAN',
#      'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=107650',
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=107650',
#      'hotelKanaName': 'ベストウェスタン\u3000おきなわおんなびーち',
#      'hotelSpecial': '【楽天トラベルブロンズアワード2021受賞】何もない贅沢がここにはある。沖縄県民割彩発見使えます。',
#      'hotelMinCharge': 4900,
#      'latitude': 95140.93,
#      'longitude': 459937.75,
#      'postalCode': '904-0417',
#      'address1': '沖縄県',
#      'address2': '国頭郡恩納村真栄田1888',
#      'telephoneNo': '098-964-1130',
#      'faxNo': '098-964-1131',
#      'access': '那覇空港から沖縄自動車道「石川ＩＣ」利用で約５０分（石川ＩＣより読谷村向け県道６号約１０分）',
#      'parkingInformation': '駐車場\u300056台（屋外）1泊500円',
#      'nearestStation': '那覇空港',
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/107650/107650.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/107650.jpg',
#      'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/107650/107650_kya.jpg',
#      'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/107650.jpg',
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/107650/107650map.gif',
#      'reviewCount': 399,
#      'reviewAverage': 4.29,
#      'userReview': '沖縄県を訪れるのは６回目です。初めてここに宿泊しました。ホテルは大き過ぎず小さ過ぎず、海に直接出ることが出来ます。３階からの海の眺望も時を忘れます。食事も地元の材料をふんだんに使ってあり、…\u30002024-02-22 10:48:54投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=107650" class="3click">つづきはこちら</a>'}},
#    {'hotelRatingInfo': {'serviceAverage': 4.24,
#      'locationAverage': 4,
#      'roomAverage': 4.69,
#      'equipmentAverage': 4.13,
#      'bathAverage': 3.8,
#      'mealAverage': 4.63}}]},
#  {'hotel': [{'hotelBasicInfo': {'hotelNo': 15963,
#      'hotelName': 'ホテル\u3000ロコイン沖縄',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=15963',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=15963&f_flg=PLAN',
#      'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=15963',
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=15963',
#      'hotelKanaName': 'ほてる\u3000ろこいんおきなわ',
#      'hotelSpecial': '【Wi-Fi完備】国際通りやオフィス街、繁華街に近く便利な立地。手作り＆健康に拘った朝食も人気です♪',
#      'hotelMinCharge': 2700,
#      'latitude': 94379.06,
#      'longitude': 459648.02,
#      'postalCode': '900-0032',
#      'address1': '沖縄県',
#      'address2': '那覇市松山1-27-11',
#      'telephoneNo': '098-869-6511',
#      'faxNo': '098-866-0078',
#      'access': '那覇空港から車で7分！ゆいレール県庁前駅より徒歩12分',
#      'parkingInformation': '1泊1000円\u3000先着順\u3000※満車の場合は近隣有料駐車場をご案内（契約外）',
#      'nearestStation': '那覇空港',
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/15963/15963.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/15963.jpg',
#      'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/15963/15963_heya.jpg',
#      'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/15963.jpg',
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/15963/15963map.gif',
#      'reviewCount': 1590,
#      'reviewAverage': 4.15,
#      'userReview': 'お値段も安く立地も良いので県内に住む私は那覇で飲んだ帰りに利用しています。\u30002024-02-23 12:52:20投稿'}},
#    {'hotelRatingInfo': {'serviceAverage': 3.86,
#      'locationAverage': 3.78,
#      'roomAverage': 3.85,
#      'equipmentAverage': 3.78,
#      'bathAverage': 3.58,
#      'mealAverage': 4.05}}]},
#  {'hotel': [{'hotelBasicInfo': {'hotelNo': 8526,
#      'hotelName': '沖縄ホテル',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=8526',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=8526&f_flg=PLAN',
#      'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=8526',
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=8526',
#      'hotelKanaName': 'おきなわほてる',
#      'hotelSpecial': '県内最古の老舗ホテルです。コンビニ徒歩1分・栄町市場や国際通りまで徒歩圏内です',
#      'hotelMinCharge': 3850,
#      'latitude': 94368.89,
#      'longitude': 459727.29,
#      'postalCode': '902-0066',
#      'address1': '沖縄県',
#      'address2': '那覇市大道35',
#      'telephoneNo': '098-884-3191',
#      'faxNo': '098-885-2102',
#      'access': '那覇空港より車で約20分・ゆいれーる安里駅徒歩約７分',
#      'parkingInformation': '50台  1泊1台1,000円   ※中・大型は要予約(別料金)',
#      'nearestStation': '那覇空港',
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/8526/8526.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/8526.jpg',
#      'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/8526/8526_war.jpg',
#      'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/8526.jpg',
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/8526/8526map.gif',
#      'reviewCount': 197,
#      'reviewAverage': 4.57,
#      'userReview': '栄町市場に近くとても夜飲みに便利な立地です。とても親切なスタッフ対応で好感が持てます。また機会があれば利用したいですね。\u30002024-02-21 09:03:13投稿'}},
#    {'hotelRatingInfo': {'serviceAverage': 4.57,
#      'locationAverage': 4.23,
#      'roomAverage': 4.34,
#      'equipmentAverage': 4.11,
#      'bathAverage': 4.22,
#      'mealAverage': 4.69}}]},
#  {'hotel': [{'hotelBasicInfo': {'hotelNo': 136808,
#      'hotelName': 'リーガロイヤルグラン沖縄',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=136808',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=136808&f_flg=PLAN',
#      'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=136808',
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=136808',
#      'hotelKanaName': 'りーがろいやるぐらんおきなわ',
#      'hotelSpecial': '空港からモノレールで10分＆旭橋駅直結！全室35平米以上＆洗い場付きバスルーム完備の客室で快適な滞在',
#      'hotelMinCharge': 7367,
#      'latitude': 94344,
#      'longitude': 459639.47,
#      'postalCode': '900-0029',
#      'address1': '沖縄県',
#      'address2': '那覇市旭町1-9',
#      'telephoneNo': '098-867-3331',
#      'faxNo': '098-867-3332',
#      'access': '【那覇空港から】車で約５分、ゆいレール「旭橋駅」下車\u3000駅から直結 【那覇バスターミナル】徒歩２分 【国際通り】徒歩１０分',
#      'parkingInformation': '有り\u3000料金：1台1泊1,500円（税・サ込）ご宿泊の皆様にバレーパーキング対応致します',
#      'nearestStation': '旭橋',
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/136808/136808.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/136808.jpg',
#      'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/136808/136808_kya.jpg',
#      'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/136808.jpg',
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/136808/136808map.gif',
#      'reviewCount': 633,
#      'reviewAverage': 4.71,
#      'userReview': '事前に問い合わせた貸し出しのヘアアイロンがすでに部屋に準備されていたりと、痒いところに手が届くという対応がすばらしかったです。ランチに予約したスパークリングワイン飲み放題のローストビーフたブッフェもと…\u30002024-02-24 19:57:30投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=136808" class="3click">つづきはこちら</a>'}},
#    {'hotelRatingInfo': {'serviceAverage': 4.62,
#      'locationAverage': 4.81,
#      'roomAverage': 4.59,
#      'equipmentAverage': 4.73,
#      'bathAverage': 4.61,
#      'mealAverage': 4.48}}]},
#  {'hotel': [{'hotelBasicInfo': {'hotelNo': 179299,
#      'hotelName': 'ヒルトン沖縄瀬底リゾート',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=179299',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=179299&f_flg=PLAN',
#      'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=179299',
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=179299',
#      'hotelKanaName': 'ひるとんおきなわせそこりぞーと',
#      'hotelSpecial': '沖縄本島北部・車で行ける離島「瀬底島」のビーチリゾート。瀬底ビーチまで徒歩2分、土曜の打ち上げ花火も',
#      'hotelMinCharge': 12430,
#      'latitude': 95923.3,
#      'longitude': 460297.14,
#      'postalCode': '905-0227',
#      'address1': '沖縄県',
#      'address2': '国頭郡本部町瀬底5750',
#      'telephoneNo': '0570-02-0701',
#      'faxNo': '0980-47-6301',
#      'access': '2025年3月まで空港直行バス運行（要予約）。 那覇空港よりレンタカーで約90分。ご宿泊様用本部港無料送迎あり（要予約）',
#      'parkingInformation': '有り 200台（宿泊客無料） ／予約不要・先着順',
#      'nearestStation': '那覇空港',
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/179299/179299.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/179299.jpg',
#      'roomImageUrl': None,
#      'roomThumbnailUrl': None,
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/179299/179299map.gif',
#      'reviewCount': 124,
#      'reviewAverage': 4.31,
#      'userReview': 'ラウンジからの夕日．土曜日開催の花火は最高でした．\u30002023-12-15 16:55:26投稿'}},
#    {'hotelRatingInfo': {'serviceAverage': 4.5,
#      'locationAverage': 4.31,
#      'roomAverage': 4.63,
#      'equipmentAverage': 4.38,
#      'bathAverage': 3.88,
#      'mealAverage': 3.81}}]},
#  {'hotel': [{'hotelBasicInfo': {'hotelNo': 171212,
#      'hotelName': '沖縄夢登\u3000－沖縄ローカルを味わう南城市にあるホテル－【Ｖａｃａｔｉｏｎ\u3000ＳＴＡＹ提供】',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=171212',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=171212&f_flg=PLAN',
#      'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=171212',
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=171212',
#      'hotelKanaName': None,
#      'hotelSpecial': '１日８組限定の地域の音色で安らぐホテル◇全室からニライカナイを眺めるオーシャンビュールーム',
#      'hotelMinCharge': 6624,
#      'latitude': 94085.4,
#      'longitude': 460035.7,
#      'postalCode': '901-0603',
#      'address1': '沖縄県',
#      'address2': '南城市玉城字百名1118-1\u3000コンドミニアムホテル沖縄夢登',
#      'telephoneNo': '050-5444-6620',
#      'faxNo': '000-000-0000',
#      'access': '首里駅から車で約２９分',
#      'parkingInformation': '有り',
#      'nearestStation': '那覇空港',
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/171212/171212.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/171212.jpg',
#      'roomImageUrl': None,
#      'roomThumbnailUrl': None,
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/171212/171212map.gif',
#      'reviewCount': 9,
#      'reviewAverage': 5,
#      'userReview': None}},
#    {'hotelRatingInfo': {'serviceAverage': 0,
#      'locationAverage': 0,
#      'roomAverage': 0,
#      'equipmentAverage': 0,
#      'bathAverage': 0,
#      'mealAverage': 0}}]},
#  {'hotel': [{'hotelBasicInfo': {'hotelNo': 167040,
#      'hotelName': 'ダブルツリーｂｙヒルトン沖縄北谷リゾート',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=167040',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=167040&f_flg=PLAN',
#      'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=167040',
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=167040',
#      'hotelKanaName': 'だぶるつりーばいひるとんおきなわちゃたんりぞーと',
#      'hotelSpecial': '美しい沖縄の西海岸を望むオーシャンフロントリゾート★アメリカンビレッジやビーチも徒歩圏内！',
#      'hotelMinCharge': 13736,
#      'latitude': 94730,
#      'longitude': 459919.51,
#      'postalCode': '904-0115',
#      'address1': '沖縄県',
#      'address2': '中頭郡北谷町美浜43',
#      'telephoneNo': '098-901-4600',
#      'faxNo': '098-901-4601',
#      'access': '那覇空港よりお車で約40分、北谷エアポートエクスプレスで約45分、有料リムジンバスで約65～80分',
#      'parkingInformation': '有り\u3000100台\u3000無料\u3000予約不要',
#      'nearestStation': '那覇空港',
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/167040/167040.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/167040.jpg',
#      'roomImageUrl': None,
#      'roomThumbnailUrl': None,
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/167040/167040map.gif',
#      'reviewCount': 59,
#      'reviewAverage': 4.5,
#      'userReview': None}},
#    {'hotelRatingInfo': {'serviceAverage': 0,
#      'locationAverage': 0,
#      'roomAverage': 0,
#      'equipmentAverage': 0,
#      'bathAverage': 0,
#      'mealAverage': 0}}]},
#  {'hotel': [{'hotelBasicInfo': {'hotelNo': 176782,
#      'hotelName': 'クラウンホテル沖縄アネックス',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=176782',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=176782&f_flg=PLAN',
#      'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=176782',
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=176782',
#      'hotelKanaName': 'くらうんほてるおきなわあねっくす',
#      'hotelSpecial': 'ブラウンを基調に落ち着いた空間！1階セブンイレブン併設♪観光・ビジネスにもお気軽に宿泊可能',
#      'hotelMinCharge': None,
#      'latitude': 94747.39,
#      'longitude': 460118.66,
#      'postalCode': '904-0021',
#      'address1': '沖縄県',
#      'address2': '沖縄市胡屋7-5-12',
#      'telephoneNo': '098-933-2777',
#      'faxNo': '098-933-2700',
#      'access': '那覇空港より車で約45分 ［マップコード: 33 562 218*47］',
#      'parkingInformation': '【 無料\u300020台\u3000予約不要\u3000※1室につき1台無料。追加1台 1,000円/日 】',
#      'nearestStation': '那覇空港',
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/176782/176782.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/176782.jpg',
#      'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/176782/176782_kan2.jpg',
#      'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/176782.jpg',
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/176782/176782map.gif',
#      'reviewCount': 53,
#      'reviewAverage': 3.8,
#      'userReview': None}},
#    {'hotelRatingInfo': {'serviceAverage': 0,
#      'locationAverage': 0,
#      'roomAverage': 0,
#      'equipmentAverage': 0,
#      'bathAverage': 0,
#      'mealAverage': 0}}]},
#  {'hotel': [{'hotelBasicInfo': {'hotelNo': 141596,
#      'hotelName': 'ホテルモントレ沖縄\u3000スパ＆リゾート',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=141596',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=141596&f_flg=PLAN',
#      'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=141596',
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=141596',
#      'hotelKanaName': 'もんとれおきなわ\u3000すぱあんどりぞーと',
#      'hotelSpecial': '沖縄有数のビーチ“タイガービーチ”に面して建つ全客室オーシャンビューのホテル。',
#      'hotelMinCharge': 11665,
#      'latitude': 95220.04,
#      'longitude': 460106.47,
#      'postalCode': '904-0413',
#      'address1': '沖縄県',
#      'address2': '国頭郡恩納村字冨着1550-1',
#      'telephoneNo': '098-993-7111',
#      'faxNo': '098-993-7112',
#      'access': '（那覇空港より）リムジンバス利用にて約65分\u3000エアポートシャトルにて約80分\u3000路線バス 系統番号120番にて約110分',
#      'parkingInformation': '有り238台500円（税込／泊）\u3000',
#      'nearestStation': '那覇空港',
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/141596/141596.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/141596.jpg',
#      'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/141596/141596_kya1.jpg',
#      'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/141596.jpg',
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/141596/141596map.gif',
#      'reviewCount': 338,
#      'reviewAverage': 4.32,
#      'userReview': '代理入力。全てにおいて大満足しました。今回は会社の同僚と一緒に見晴らしのいい部屋に宿泊。料金に見合ったサービスやアメニティで、次は家族で訪れたいと思いました。\u30002024-02-13 16:01:35投稿'}},
#    {'hotelRatingInfo': {'serviceAverage': 4.23,
#      'locationAverage': 4.61,
#      'roomAverage': 4.62,
#      'equipmentAverage': 4.28,
#      'bathAverage': 4.16,
#      'mealAverage': 3.87}}]},
#  {'hotel': [{'hotelBasicInfo': {'hotelNo': 172439,
#      'hotelName': 'グランディスタイル\u3000沖縄\u3000読谷\u3000ホテル＆リゾート',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=172439',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=172439&f_flg=PLAN',
#      'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=172439',
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=172439',
#      'hotelKanaName': 'ぐらんでぃすたいる\u3000おきなわ\u3000よみたん\u3000ほてるあんどりぞーと',
#      'hotelSpecial': '暮らすように穏やかに。極上の癒しを楽しむ大人のリゾート。エリアで唯一の、屋外温水インフィニティプール',
#      'hotelMinCharge': 13000,
#      'latitude': 95092.1,
#      'longitude': 459840.91,
#      'postalCode': '904-0325',
#      'address1': '沖縄県',
#      'address2': '中頭郡読谷村字瀬名波571番1',
#      'telephoneNo': '098-987-8300',
#      'faxNo': '098-987-8304',
#      'access': '那覇空港よりお車にて約５０分',
#      'parkingInformation': '有り\u3000無料',
#      'nearestStation': '那覇空港',
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/172439/172439.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/172439.jpg',
#      'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/172439/172439_kan1.jpg',
#      'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/172439.jpg',
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/172439/172439map.gif',
#      'reviewCount': 91,
#      'reviewAverage': 4.84,
#      'userReview': 'とてもゆったりした時間を過ごせるリゾートホテルでした。スタッフさんたちのホスピタリティあふれる対応にも感動しました。朝食はテイクアウトできて、部屋のバルコニーのソファでいただきました。海風を感じな…\u30002024-02-21 21:43:22投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=172439" class="3click">つづきはこちら</a>'}},
#    {'hotelRatingInfo': {'serviceAverage': 4.84,
#      'locationAverage': 4.21,
#      'roomAverage': 4.95,
#      'equipmentAverage': 4.74,
#      'bathAverage': 4.58,
#      'mealAverage': 4.89}}]},
#  {'hotel': [{'hotelBasicInfo': {'hotelNo': 182861,
#      'hotelName': '沖縄プリンスホテル\u3000オーシャンビューぎのわん',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=182861',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=182861&f_flg=PLAN',
#      'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=182861',
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=182861',
#      'hotelKanaName': 'おきなわぷりんすほてる\u3000おーしゃんびゅーぎのわん',
#      'hotelSpecial': '全室オーシャンビュールーム！通年利用出来るインフィニティプールに大浴場・サウナ・岩盤浴等有。',
#      'hotelMinCharge': 8615,
#      'latitude': 94582.55,
#      'longitude': 459843.21,
#      'postalCode': '901-2224',
#      'address1': '沖縄県',
#      'address2': '宜野湾市真志喜3丁目28-１',
#      'telephoneNo': '098-898-1110',
#      'faxNo': '098-943-6061',
#      'access': '那覇空港から車で30分/ホテル直通の空港リムジンバスで40分（要予約制）/路線バス、コンベンションセンター前降車徒歩6分',
#      'parkingInformation': '有り（宿泊者無料）、立体駐車場を含む２１３台（先着順）',
#      'nearestStation': '那覇空港',
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/182861/182861.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/182861.jpg',
#      'roomImageUrl': None,
#      'roomThumbnailUrl': None,
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/182861/182861map.gif',
#      'reviewCount': 87,
#      'reviewAverage': 4.77,
#      'userReview': '以前宿泊した時\u3000岩盤浴やプールも良かったのとスタッフの皆さんがとても親切で楽しかったので\u3000今回2泊またしてきました。今回は朝食なしのクラブツインの部屋にしました。毎日違うメニューが出て美味しかった…\u30002024-01-09 17:17:49投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=182861" class="3click">つづきはこちら</a>'}},
#    {'hotelRatingInfo': {'serviceAverage': 4.58,
#      'locationAverage': 4.39,
#      'roomAverage': 4.8,
#      'equipmentAverage': 4.52,
#      'bathAverage': 4.42,
#      'mealAverage': 4.3}}]},
#  {'hotel': [{'hotelBasicInfo': {'hotelNo': 179405,
#      'hotelName': '青と碧と白と沖縄',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=179405',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=179405&f_flg=PLAN',
#      'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=179405',
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=179405',
#      'hotelKanaName': 'あおとあおとしろとおきなわ',
#      'hotelSpecial': '非日常と避“密”の限定3室！ディズニー出身のオーナーと建築家中村拓志氏が手掛けた感動空間',
#      'hotelMinCharge': 17000,
#      'latitude': 95098.46,
#      'longitude': 459880.94,
#      'postalCode': '904-0417',
#      'address1': '沖縄県',
#      'address2': '国頭郡恩納村真栄田3537-2',
#      'telephoneNo': '070-2631-6196',
#      'faxNo': '\u3000',
#      'access': '那覇空港よりお車にて約60分',
#      'parkingInformation': '有り\u3000５台\u3000無料【マップコード】33 884 851 *01\u3000※対応アプリ等でご利用ください。',
#      'nearestStation': '那覇空港',
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/179405/179405.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/179405.jpg',
#      'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/179405/179405_room.jpg',
#      'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/179405.jpg',
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/179405/179405map.gif',
#      'reviewCount': 25,
#      'reviewAverage': 5,
#      'userReview': None}},
#    {'hotelRatingInfo': {'serviceAverage': 0,
#      'locationAverage': 0,
#      'roomAverage': 0,
#      'equipmentAverage': 0,
#      'bathAverage': 0,
#      'mealAverage': 0}}]},
#  {'hotel': [{'hotelBasicInfo': {'hotelNo': 165955,
#      'hotelName': 'Ｓｅａ\u3000Ｓｔａｙ\u3000Ｏｋｉｎａｗａ\u3000シーステイ沖縄',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=165955',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=165955&f_flg=PLAN',
#      'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=165955',
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=165955',
#      'hotelKanaName': 'シー\u3000ステイ\u3000オキナワ',
#      'hotelSpecial': '【谷茶ビーチまで徒歩約2分】設備充実の一棟貸し！長期滞在に最適＜系列飲食店・アクティビティ割引あり＞',
#      'hotelMinCharge': 3850,
#      'latitude': 95265.47,
#      'longitude': 460177.96,
#      'postalCode': '904-0412',
#      'address1': '沖縄県',
#      'address2': '国頭郡恩納村谷茶16-3',
#      'telephoneNo': '090-7227-8355',
#      'faxNo': '050-3451-1030',
#      'access': '那覇空港よりお車にて約60分',
#      'parkingInformation': '無料駐車（普通車２台\u3000or\u3000小型車３台）',
#      'nearestStation': '那覇空港',
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/165955/165955.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/165955.jpg',
#      'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/165955/165955_kan1.jpg',
#      'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/165955.jpg',
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/165955/165955map.gif',
#      'reviewCount': 2,
#      'reviewAverage': None,
#      'userReview': None}},
#    {'hotelRatingInfo': {'serviceAverage': None,
#      'locationAverage': None,
#      'roomAverage': None,
#      'equipmentAverage': None,
#      'bathAverage': None,
#      'mealAverage': None}}]},
#  {'hotel': [{'hotelBasicInfo': {'hotelNo': 137367,
#      'hotelName': 'メルキュールホテル沖縄那覇',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=137367',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=137367&f_flg=PLAN',
#      'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=137367',
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=137367',
#      'hotelKanaName': 'めるきゅーるほてるおきなわなは',
#      'hotelSpecial': '空港から最短9分！壷川駅より徒歩1分、館内にレンタカーデスクあり。ビジネスや観光の拠点として最適♪',
#      'hotelMinCharge': 4350,
#      'latitude': 94325.98,
#      'longitude': 459651.43,
#      'postalCode': '900-0025',
#      'address1': '沖縄県',
#      'address2': '那覇市壺川3-3-19',
#      'telephoneNo': '098-855-7111',
#      'faxNo': '098-855-7112',
#      'access': '那覇空港より最短9分！ゆいレール壺川駅より徒歩1分（駅前）。',
#      'parkingInformation': '1泊1000円（144台、先着順、車サイズ制限あり）入庫不可時は近隣駐車場をご利用ください。',
#      'nearestStation': None,
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/137367/137367.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/137367.jpg',
#      'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/137367/137367_kya.jpg',
#      'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/137367.jpg',
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/137367/137367map.gif',
#      'reviewCount': 737,
#      'reviewAverage': 4.25,
#      'userReview': '清潔で気持ちよく利用出来ました。フロントの対応も丁寧です。朝食は品数はそこまで多くはありませんが、どれも非常に美味しくて質の高さを感じました。特にクロワッサンが美味しかったと家族にも好評で…\u30002024-02-20 17:48:06投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=137367" class="3click">つづきはこちら</a>'}},
#    {'hotelRatingInfo': {'serviceAverage': 4,
#      'locationAverage': 4.67,
#      'roomAverage': 4.06,
#      'equipmentAverage': 3.89,
#      'bathAverage': 3.8,
#      'mealAverage': 4.43}}]},
#  {'hotel': [{'hotelBasicInfo': {'hotelNo': 182630,
#      'hotelName': 'オリエンタルホテル\u3000沖縄リゾート＆スパ',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=182630',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=182630&f_flg=PLAN',
#      'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=182630',
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=182630',
#      'hotelKanaName': 'おりえんたるほてる\u3000おきなわりぞーとすぱ',
#      'hotelSpecial': '288 室が2023年12月23日より順次リニューアルオープン！やんばるを体験する「旅」の拠点に。',
#      'hotelMinCharge': 7370,
#      'latitude': 95494.15,
#      'longitude': 460567.73,
#      'postalCode': '905-0026',
#      'address1': '沖縄県',
#      'address2': '名護市喜瀬1490-1',
#      'telephoneNo': '0980-51-1000',
#      'faxNo': '0980-51-1001',
#      'access': '那覇空港より沖縄自動車道利用で約70分',
#      'parkingInformation': '有\u30001滞在1,000円',
#      'nearestStation': '那覇空港',
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/182630/182630.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/182630.jpg',
#      'roomImageUrl': None,
#      'roomThumbnailUrl': None,
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/182630/182630map.gif',
#      'reviewCount': 332,
#      'reviewAverage': 4.36,
#      'userReview': '部屋は最高のロケーションでした！食事も大満足でしたが、食事を提供しているスタッフの態度が酷かったです。ハンバーガーが崩れお皿から落ちてしまったので、再度作っているスタッフにお願いしたところ、明からさま…\u30002024-02-24 23:14:04投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=182630" class="3click">つづきはこちら</a>'}},
#    {'hotelRatingInfo': {'serviceAverage': 4.34,
#      'locationAverage': 4.18,
#      'roomAverage': 4.43,
#      'equipmentAverage': 4.45,
#      'bathAverage': 4.03,
#      'mealAverage': 4.33}}]},
#  {'hotel': [{'hotelBasicInfo': {'hotelNo': 177851,
#      'hotelName': '星のや沖縄',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=177851',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=177851&f_flg=PLAN',
#      'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=177851',
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=177851',
#      'hotelKanaName': 'ほしのやおきなわ',
#      'hotelSpecial': '全ての客室がオーシャンフロント。美しい海を眺めて暮らすように滞在する、沖縄の贅沢を感じられるリゾート',
#      'hotelMinCharge': 17722,
#      'latitude': 95092.68,
#      'longitude': 459779.51,
#      'postalCode': '904-0327',
#      'address1': '沖縄県',
#      'address2': '中頭郡読谷村儀間474',
#      'telephoneNo': '050-3134-8091',
#      'faxNo': None,
#      'access': '那覇空港よりお車にて約１時間',
#      'parkingInformation': '有り\u3000１００台\u3000無料\u3000予約不要',
#      'nearestStation': '那覇空港',
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/177851/177851.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/177851.jpg',
#      'roomImageUrl': None,
#      'roomThumbnailUrl': None,
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/177851/177851map.gif',
#      'reviewCount': 35,
#      'reviewAverage': 4.73,
#      'userReview': None}},
#    {'hotelRatingInfo': {'serviceAverage': 0,
#      'locationAverage': 0,
#      'roomAverage': 0,
#      'equipmentAverage': 0,
#      'bathAverage': 0,
#      'mealAverage': 0}}]},
#  {'hotel': [{'hotelBasicInfo': {'hotelNo': 28077,
#      'hotelName': '沖縄家庭料理の宿\u3000なかはら',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=28077',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=28077&f_flg=PLAN',
#      'dpPlanListUrl': None,
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=28077',
#      'hotelKanaName': 'おきなわかていりょうりのやど\u3000なかはら',
#      'hotelSpecial': '空港からバスで１本の好立地！那覇を一望できる高台からの眺望が自慢です。朝食は沖縄家庭料理をご提供。',
#      'hotelMinCharge': 5600,
#      'latitude': 94378.12,
#      'longitude': 459770.72,
#      'postalCode': '903-0825',
#      'address1': '沖縄県',
#      'address2': '那覇市首里山川町1-69-3',
#      'telephoneNo': '098-887-7073',
#      'faxNo': '098-887-7073',
#      'access': '空港からタクシーで約２０分｜空港からバス125番に乗車→山川下車→徒歩２０秒｜国際通りからバスで１５分',
#      'parkingInformation': '有り\u3000３台\u3000無料\u3000（ご予約承りますので、予めご連絡ください。無き場合は先着順）',
#      'nearestStation': '那覇空港',
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/28077/28077.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/28077.jpg',
#      'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/28077/28077_k.jpg',
#      'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/28077.jpg',
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/28077/28077map.gif',
#      'reviewCount': 31,
#      'reviewAverage': 4.67,
#      'userReview': None}},
#    {'hotelRatingInfo': {'serviceAverage': 0,
#      'locationAverage': 0,
#      'roomAverage': 0,
#      'equipmentAverage': 0,
#      'bathAverage': 0,
#      'mealAverage': 0}}]},
#  {'hotel': [{'hotelBasicInfo': {'hotelNo': 167519,
#      'hotelName': 'ノボテル沖縄那覇',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=167519',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=167519&f_flg=PLAN',
#      'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=167519',
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=167519',
#      'hotelKanaName': 'のぼてる\u3000おきなわ\u3000なは',
#      'hotelSpecial': '国際通りも徒歩圏内、 観光の拠点としても便利な立地。最上階プレミアラウンジは１ランク上の滞在を演出。',
#      'hotelMinCharge': 5950,
#      'latitude': 94374.59,
#      'longitude': 459750.57,
#      'postalCode': '902-0062',
#      'address1': '沖縄県',
#      'address2': '那覇市松川40番地',
#      'telephoneNo': '098-887-1111',
#      'faxNo': '098-886-5591',
#      'access': '那覇空港から車で約25分、ゆいレール安里駅よりタクシーで約５分／徒歩約２０分',
#      'parkingInformation': '有り（1泊1台1,000円）\u3000※事前予約不可',
#      'nearestStation': None,
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/167519/167519.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/167519.jpg',
#      'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/167519/167519_room.jpg',
#      'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/167519.jpg',
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/167519/167519map.gif',
#      'reviewCount': 408,
#      'reviewAverage': 4.48,
#      'userReview': '首里城の近くで高台にあり、ラウンジや部屋からの眺めは大変良かったです。今回は早めにホテルに戻ってラウンジの軽食やお酒を頂きました。沖縄料理にこだわらなければ、夕食の代わりになると思います。朝食は沖縄料…\u30002024-02-19 13:50:58投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=167519" class="3click">つづきはこちら</a>'}},
#    {'hotelRatingInfo': {'serviceAverage': 4.35,
#      'locationAverage': 3.78,
#      'roomAverage': 4.24,
#      'equipmentAverage': 4.29,
#      'bathAverage': 4,
#      'mealAverage': 4.32}}]},
#  {'hotel': [{'hotelBasicInfo': {'hotelNo': 183103,
#      'hotelName': 'ＴＨＥ\u3000ＧＲＡＮＤ\u3000ＨＯＴＥＬ\u3000ＧＩＮＯＷＡＮ\u3000オーシャン＆シティビューの新しい沖縄のホテル',
#      'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=183103',
#      'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=183103&f_flg=PLAN',
#      'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=183103',
#      'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=183103',
#      'hotelKanaName': 'ザグランドホテルギノワン\u3000オーシャン＆シティビュー',
#      'hotelSpecial': '抜群のアクセスとロケーションで沖縄観光の拠点に！全室バルコニー付',
#      'hotelMinCharge': 3500,
#      'latitude': 94603.43,
#      'longitude': 459913.94,
#      'postalCode': '901-2223',
#      'address1': '沖縄県',
#      'address2': '宜野湾市大山3-5-1',
#      'telephoneNo': '098-898-7700',
#      'faxNo': '098-898-7701',
#      'access': '那覇空港から車で30分',
#      'parkingInformation': '有り  52台完備（無料・先着順・予約不可）',
#      'nearestStation': '那覇空港',
#      'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/183103/183103.jpg',
#      'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/183103.jpg',
#      'roomImageUrl': None,
#      'roomThumbnailUrl': None,
#      'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/183103/183103map.gif',
#      'reviewCount': 81,
#      'reviewAverage': 4.46,
#      'userReview': 'コメントを書きたくなるいいホテルでしたので、書き込みます。\u30002月の恒例のベイスターズの宜野湾キャンプ観戦も兼ねた旅のお宿として選びました！国道58号線のど真ん前で那覇からのアクセ良好！しかも施設内にフ…\u30002024-02-20 16:15:19投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=183103" class="3click">つづきはこちら</a>'}},
#    {'hotelRatingInfo': {'serviceAverage': 4.54,
#      'locationAverage': 4.29,
#      'roomAverage': 4.5,
#      'equipmentAverage': 4.15,
#      'bathAverage': 3.96,
#      'mealAverage': 0}}]}]

# %%
hotel = hotels[0]['hotel'][0]['hotelBasicInfo']
hotel
# Out:
# {'hotelNo': 30045,
#  'hotelName': 'グランドメルキュール沖縄残波岬リゾート（旧ロイヤルホテル沖縄残波岬）',
#  'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/JBe8h/?f_no=30045',
#  'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/3VTwt/?f_no=30045&f_flg=PLAN',
#  'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/IWrzP/?noTomariHotel=30045',
#  'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=30045',
#  'hotelKanaName': 'ぐらんどめるきゅーるおきなわざんぱみさきりぞーと',
#  'hotelSpecial': '24年8月県内最大級のプールOPEN。全客室にお酒やソフトドリンク、軽食が楽しめるラウンジアクセス付',
#  'hotelMinCharge': None,
#  'latitude': 95153.13,
#  'longitude': 459791.38,
#  'postalCode': '904-0394',
#  'address1': '沖縄県',
#  'address2': '中頭郡読谷村字宇座1575',
#  'telephoneNo': '098-958-5000',
#  'faxNo': '098-958-3970',
#  'access': '那覇空港より国道５８号線を名護方面へ読谷村伊良皆交差点を残波岬方面へ。車で70分。',
#  'parkingInformation': '有(無料）',
#  'nearestStation': '那覇空港',
#  'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/30045/30045.jpg',
#  'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/30045.jpg',
#  'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/30045/30045_s.jpg',
#  'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/30045.jpg',
#  'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/30045/30045map.gif',
#  'reviewCount': 967,
#  'reviewAverage': 4.09,
#  'userReview': '工事中と修学旅行生が一緒だったので、少し騒がしく感じました。ウエルカムビールがとても助かりました。朝食ビュフェも、品数がとても多く、景観の良いところで、とても満足しました。ミニハンバーガー…\u30002023-12-25 16:31:04投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/kw/HTX0u/?f_hotel_no=30045" class="3click">つづきはこちら</a>'}

# %%
hotel['access']
# Out:
# '那覇空港より国道５８号線を名護方面へ読谷村伊良皆交差点を残波岬方面へ。車で70分。'

# %%
hotel['address1'] + hotel['address2']
# Out:
# '沖縄県中頭郡読谷村字宇座1575'
