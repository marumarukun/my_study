# %%
'''
1. GPUが使用可能であればデバイスに割り当てる
'''
import torch
# GPUが使用可能であれば割り当てる
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print('使用されるデバイス：', device)
# Out:
# 使用されるデバイス： cuda

# %%
'''
2. 「ObjectDetection」内のモジュールをインポート可能にする
'''
import sys

# モジュールのインポートが行えるように「ObjectDetection」のパスを登録
# 以下のパスは環境に合わせて書き換える必要があります
sys.path.append('/content/drive/MyDrive/Colab Notebooks/ObjectDetection')

# %%
'''
3. データローダーの作成
'''
import torch.utils.data as data
# vocモジュールからインポート
from voc import make_filepath_list, GetBBoxAndLabel, DataTransform, \
                PreprocessVOC2012, multiobject_collate_fn

# データセットの親フォルダーのパス
# 以下のパスは環境に合わせて書き換える必要があります
rootpath = "/content/drive/MyDrive/Colab Notebooks/ObjectDetection/data/VOCdevkit/VOC2012/"
# 訓練用、検証用の画像、アノテーションデータのファイルパスのリストを作成
train_img_list, train_anno_list, val_img_list, val_anno_list = make_filepath_list(
    rootpath)

# VOC2012の正解ラベルのリスト
voc_classes = [
    'aeroplane', 'bicycle', 'bird', 'boat', 'bottle',
    'bus', 'car', 'cat', 'chair', 'cow',
    'diningtable', 'dog', 'horse', 'motorbike',
    'person', 'pottedplant', 'sheep', 'sofa', 'train',
    'tvmonitor']

# データセットのRGBの平均値(R)123,(G)117,(B)104をOpenCVのBGRの並びに合わせて
# (104, 117, 123)のタプルにする
color_mean = (104, 117, 123)

# 画像を入力サイズを300×300にする
input_size = 300

# DataTransformでVOC2012データセットを前処理して以下のデータを取得
#  ・前処理後のイメージ[R,G,B](Tensor)
#  ・BBoxとラベル(ndarray)
#  ・イメージの高さ、幅(int)
train_dataset = PreprocessVOC2012(
    train_img_list,  # イメージのパスリスト
    train_anno_list, # アノテーションのパスリスト
    phase="train",   # 訓練モード
    transform=DataTransform(input_size, color_mean), # 前処理オブジェクト
    get_bbox_label=GetBBoxAndLabel(voc_classes)) # BBoxとラベル取得

val_dataset = PreprocessVOC2012(
    val_img_list,  # イメージのパスリスト
    val_anno_list, # アノテーションのパスリスト
    phase="val",   # 訓練モード
    transform=DataTransform(input_size, color_mean), # 前処理オブジェクト
    get_bbox_label=GetBBoxAndLabel(voc_classes)) # BBoxとラベル取得

batch_size = 32 # 1バッチあたりのデータ数は32

# 訓練用のミニバッチを生成するデータローダー
train_dataloader = data.DataLoader(
    train_dataset,         # 前処理した訓練データ
    batch_size=batch_size, # バッチサイズ
    shuffle=True, # ミニバッチ抽出の際にシャッフルする
    collate_fn=multiobject_collate_fn) # ミニバッチ生成関数

# 検証用のミニバッチを生成するデータローダー
val_dataloader = data.DataLoader(
    val_dataset,           # 前処理した検証データ
    batch_size=batch_size, # バッチサイズ
    shuffle=False, # ミニバッチ抽出の際にシャッフルしない
    collate_fn=multiobject_collate_fn) # ミニバッチ生成関数

# 辞書オブジェクトにまとめる
dataloaders_dict = {"train": train_dataloader, "val": val_dataloader}

# %%
'''
4. torchinfoをpipコマンドでインストールする
'''
pip install torchinfo

# %%
'''
5. SSDモデルの作成
'''
import torch.nn as nn
import torch.nn.init as init
from ssd import SSD # ssdモジュールのインポート
from torchinfo import summary

# SSDモデルの設定値
ssd_cfg = {
    'classes_num': 21,  # 背景クラスを含めた合計クラス数
    'input_size': 300,  # 画像の入力サイズ
    'dbox_num': [4, 6, 6, 6, 4, 4],  # DBoxのアスペクト比の種類
    'feature_maps': [38, 19, 10, 5, 3, 1],  # 各sourceの画像サイズ
    'steps': [8, 16, 32, 64, 100, 300],  # DBOXの大きさを決める
    'min_sizes': [30, 60, 111, 162, 213, 264],  # DBOXの大きさを決める
    'max_sizes': [60, 111, 162, 213, 264, 315],  # DBOXの大きさを決める
    'aspect_ratios': [[2], [2, 3], [2, 3], [2, 3], [2], [2]],
}

# SSDモデルを生成
net = SSD(phase='train', # 訓練モード
          cfg=ssd_cfg)   # 設定値のdictオブジェクト

# SSDの初期の重みを設定
# VGG16の学習済み重みを取得
vgg_weights = torch.load(
    '/content/drive/MyDrive/Colab Notebooks/ObjectDetection/weights/vgg16_reducedfc.pth')
# SSDのvggネットワークの重みとしてロード
net.vgg.load_state_dict(vgg_weights)

# SSDモデルのvgg以外のネットワークの重みはHeの初期値で初期化
def weights_init(m):
    if isinstance(m, nn.Conv2d):
        init.kaiming_normal_(m.weight.data)
        if m.bias is not None:  # バイアス項がある場合
            nn.init.constant_(m.bias, 0.0)

# Heの初期値を適用
net.extras.apply(weights_init) # extrasネットワーク
net.loc.apply(weights_init)    # locネットワーク
net.conf.apply(weights_init)   #confネットワーク

# SSDモデルのサマリを出力
summary(
    net,
    # バッチを含む入力のサイズを設定
    input_size=(batch_size, 3, 300, 300),
    # レイヤーへの入力、出力のサイズとパラメーター数を出力
    col_names=['input_size','output_size', 'num_params'])

# %%
'''
6. 損失関数とオプティマイザーの作成
'''
import torch.optim as optim
from ssd import MultiBoxLoss

# 損失関数のオブジェクトを生成
criterion = MultiBoxLoss(
    jaccard_thresh=0.5, # 背景のDBoxに分類するときのIoUの閾値
    neg_pos=3, # 背景のDBoxの数はPositive DBoxの何倍にするか
    device=device) # ネットワークのTensorに割り当てるデバイス

# 勾配降下アルゴリズムを使用するオプティマイザーを生成
optimizer = optim.SGD(
    net.parameters(),  # SSDモデルのパラメーター
    lr=1e-3,           # 学習率
    momentum=0.9,      # 慣性項に割り当てる係数
    weight_decay=5e-4) # 重み更新時のL2正則化の係数

# %%
'''
7. SSDモデルの学習(パラメーターの更新)を行う関数
'''
import time
import pandas as pd

def train(net, dataloaders_dict, criterion, optimizer, num_epochs):
    '''
    Parameters:
      net(object): SSDモデル
      dataloaders_dict(objectのdict): データーローダー
      criterion(object): 損失関数
      optimizer(object): オプティマイザー
      num_epochs(object): 学習回数
    '''
    # SSDモデルでGPUを使用
    net.to(device)

    # ネットワークの構成に対して最適なアルゴリズムを見つけて高速化させる
    torch.backends.cudnn.benchmark = True

    iteration = 1          # イテレーション(ステップ)カウンター
    epoch_train_loss = 0.0 # 訓練1エポックごとの損失和
    epoch_val_loss = 0.0   # 検証1エポックごとの損失和
    logs = []              # 損失のログを記録するリスト

    # 学習、または検証のエポックごとのループ
    for epoch in range(num_epochs):
        # 開始時刻を保存
        t_epoch_start = time.time()
        t_iter_start = time.time()

        # 現在のエポック数を出力
        print('---------------------------------------')
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('---------------------------------------')

        # エポック10回につき検証を1回行う
        for phase in ['train', 'val']:
            # エポックが10回に達するまではモデルを訓練モードにする
            if phase == 'train':
                net.train()  # モデルを訓練モードにする
            else:
                # エポックが10回に達していたらモデルを検証モードにして検証開始
                if((epoch+1) % 10 == 0):
                    net.eval()   # モデルを検証モードにする
                    print('---------------------------------------')
                    print('（validation）')
                else:
                    # 10回に達していなければ次のエポックに進む
                    continue

            # 1ステップにおけるミニバッチを使用した学習または検証
            # データローダーをイテレートしてミニバッチを抽出
            for images, targets in dataloaders_dict[phase]:
                # 画像データにデバイスを割り当てる
                images = images.to(device)
                # 教師データ(正解BBoxのアノテーション情報)
                # (バッチサイズ, 物体数, 5[xmin, ymin, xmax, ymax, label_index])
                # にデバイスを割り当てる
                targets = [ann.to(device) for ann in targets]

                # optimizerが保持する勾配を0で初期化(累積しないように)
                optimizer.zero_grad()

                # 順伝搬（forward）とバックプロパゲーション(訓練時のみ)
                with torch.set_grad_enabled(phase == 'train'):
                    # 順伝搬（forward）を行って(loc, conf, dbox_list)を取得
                    # ・locの出力(バッチサイズ, 8732, 4[Δcx, Δcy, Δw, Δh])
                    # ・confの出力(バッチサイズ, 8732, 21)
                    # ・DBoxの情報(8732, 4[cx, cy, width, height])
                    outputs = net(images)

                    # Positive DBoxのオフセット情報の損失平均
                    # ミニバッチにおけるPositive DBoxの確信度の損失平均
                    loss_l, loss_c = criterion(outputs, targets)
                    # 2つの損失を合計する
                    loss = loss_l + loss_c

                    # 訓練時はバックプロパゲーションによるパラメーター更新を行う
                    if phase == 'train':
                        loss.backward()  # バックプロパゲーション

                        # 勾配が大きすぎると不安定になるので
                        # clipで勾配の上限を2.0に制限する
                        nn.utils.clip_grad_value_(net.parameters(),
                                                  clip_value=2.0)
                        # 勾配降下法の更新式を適用してバイアス、重みを更新
                        optimizer.step()

                        # ミニバッチを10個処理(10ステップ)ごとに損失を出力
                        if (iteration % 10 == 0):
                            # 10ステップの所要時間を取得
                            t_iter_finish = time.time()
                            duration = t_iter_finish - t_iter_start
                            # ステップ数、損失、所要時間を出力
                            print('ステップ( {} )  loss: {:.4f} -- time: {:.4f} sec.'.format(
                                iteration, loss.item(), duration))
                            t_iter_start = time.time()

                        # エポックの損失をepoch_train_lossに加算する
                        epoch_train_loss += loss.item()
                        # ステップ数を1増やす
                        iteration += 1

                    # 検証モードでは順伝播後の損失の記録のみを行う
                    else:
                        epoch_val_loss += loss.item()

        # epochのphaseごとのlossと正解率
        # エポック終了時の時刻を取得
        t_epoch_finish = time.time()
        print('---------------------------------------')
        # 訓練データの損失と検証データの損失を出力
        print('train_loss: {:.4f} - val_loss(Every 10 epochs): {:.4f}'.format(
            epoch_train_loss, epoch_val_loss))
        # エポック終了までに要した時間を取得
        print('time:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        # 次のエポックの開始時刻を取得
        t_epoch_start = time.time()

        # エポックごとに損失をdictオブジェクトに保存
        log_epoch = {'epoch': epoch+1,
                     'train_loss': epoch_train_loss,
                     'val_loss': epoch_val_loss}
        # ログのリストに追加
        logs.append(log_epoch)
        # ログのリストをデータフレームに変換
        df = pd.DataFrame(logs)
        # ログファイルに保存
        df.to_csv('/content/drive/MyDrive/Colab Notebooks/ObjectDetection/epoch_loss.csv')

        # 訓練時の損失和を0で初期化
        epoch_train_loss = 0.0
        # 検証時の損失和を0で初期化
        epoch_val_loss = 0.0

        # 1エポック終了ごとにモデルのパラメーター値を保存
        if ((epoch+1) % 10 == 0):
            torch.save(
                net.state_dict(),
                '/content/drive/MyDrive/Colab Notebooks/ObjectDetection/weights/ssd_weights' +
                str(epoch+1) + '.pth')
            print('--saved weights--')

# %%
# %%time
'''
8. VOC2012データセットをSSDモデルで学習
'''
num_epochs= 50 # 学習回数(エポック数)は50

train(net,                   # SSDモデル
      dataloaders_dict,      # データローダー
      criterion,             # 損失関数
      optimizer,             # オプティマイザー
      num_epochs=num_epochs) # エポック数
# Out:
# ---------------------------------------
# Epoch 1/50
# ---------------------------------------
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ステップ( 10 )  loss: 15.6517 -- time: 322.1056 sec.
# ステップ( 20 )  loss: 12.3415 -- time: 143.3154 sec.
# ステップ( 30 )  loss: 10.4748 -- time: 142.4835 sec.
# ステップ( 40 )  loss: 11.6375 -- time: 141.6629 sec.
# ステップ( 50 )  loss: 9.0556 -- time: 152.8027 sec.
# ステップ( 60 )  loss: 8.5087 -- time: 143.0720 sec.
# ステップ( 70 )  loss: 8.4185 -- time: 142.2496 sec.
# ステップ( 80 )  loss: 8.1664 -- time: 158.5785 sec.
# ステップ( 90 )  loss: 7.9248 -- time: 141.5801 sec.
# ステップ( 100 )  loss: 7.5071 -- time: 139.5022 sec.
# ステップ( 110 )  loss: 8.0813 -- time: 142.7546 sec.
# ステップ( 120 )  loss: 8.3672 -- time: 146.8860 sec.
# ステップ( 130 )  loss: 7.0907 -- time: 141.6032 sec.
# ステップ( 140 )  loss: 8.5033 -- time: 139.8491 sec.
# ステップ( 150 )  loss: 7.4593 -- time: 141.4293 sec.
# ステップ( 160 )  loss: 7.5174 -- time: 145.3636 sec.
# ステップ( 170 )  loss: 7.7389 -- time: 138.6799 sec.
# ---------------------------------------
# train_loss: 1707.6666 - val_loss(Every 10 epochs): 0.0000
# time:  2765.9350 sec.
# ---------------------------------------
# Epoch 2/50
# ---------------------------------------
# ステップ( 180 )  loss: 8.4445 -- time: 1.1316 sec.
# ステップ( 190 )  loss: 7.6089 -- time: 18.3229 sec.
# ステップ( 200 )  loss: 8.2785 -- time: 18.5159 sec.
# ステップ( 210 )  loss: 7.7166 -- time: 18.3633 sec.
# ステップ( 220 )  loss: 7.7114 -- time: 18.2975 sec.
# ステップ( 230 )  loss: 7.3621 -- time: 18.6652 sec.
# ステップ( 240 )  loss: 8.6784 -- time: 18.5232 sec.
# ステップ( 250 )  loss: 8.2981 -- time: 18.3099 sec.
# ステップ( 260 )  loss: 7.2784 -- time: 18.4674 sec.
# ステップ( 270 )  loss: 8.9108 -- time: 18.7047 sec.
# ステップ( 280 )  loss: 8.9040 -- time: 18.9820 sec.
# ステップ( 290 )  loss: 7.3349 -- time: 18.6095 sec.
# ステップ( 300 )  loss: 8.1136 -- time: 18.4338 sec.
# ステップ( 310 )  loss: 7.7609 -- time: 18.3578 sec.
# ステップ( 320 )  loss: 8.7085 -- time: 18.5089 sec.
# ステップ( 330 )  loss: 7.2891 -- time: 18.5891 sec.
# ステップ( 340 )  loss: 7.0281 -- time: 18.4242 sec.
# ステップ( 350 )  loss: 7.1988 -- time: 18.4667 sec.
# ---------------------------------------
# train_loss: 1376.0642 - val_loss(Every 10 epochs): 0.0000
# time:  345.2565 sec.
# ---------------------------------------
# Epoch 3/50
# ---------------------------------------
# ステップ( 360 )  loss: 7.0070 -- time: 2.9846 sec.
# ステップ( 370 )  loss: 6.8007 -- time: 18.9590 sec.
# ステップ( 380 )  loss: 6.9608 -- time: 18.8884 sec.
# ステップ( 390 )  loss: 7.0833 -- time: 18.8130 sec.
# ステップ( 400 )  loss: 6.8678 -- time: 18.5539 sec.
# ステップ( 410 )  loss: 7.3054 -- time: 18.6270 sec.
# ステップ( 420 )  loss: 6.8495 -- time: 18.5420 sec.
# ステップ( 430 )  loss: 6.8717 -- time: 18.3120 sec.
# ステップ( 440 )  loss: 6.9735 -- time: 18.7112 sec.
# ステップ( 450 )  loss: 6.6885 -- time: 18.6736 sec.
# ステップ( 460 )  loss: 6.9649 -- time: 18.0268 sec.
# ステップ( 470 )  loss: 6.7597 -- time: 18.6893 sec.
# ステップ( 480 )  loss: 6.8144 -- time: 18.5144 sec.
# ステップ( 490 )  loss: 6.5245 -- time: 18.5759 sec.
# ステップ( 500 )  loss: 6.5720 -- time: 18.3548 sec.
# ステップ( 510 )  loss: 6.7300 -- time: 18.2641 sec.
# ステップ( 520 )  loss: 6.7556 -- time: 18.3995 sec.
# ステップ( 530 )  loss: 6.3522 -- time: 18.1524 sec.
# ---------------------------------------
# train_loss: 1235.7197 - val_loss(Every 10 epochs): 0.0000
# time:  345.4742 sec.
# ---------------------------------------
# Epoch 4/50
# ---------------------------------------
# ステップ( 540 )  loss: 6.2340 -- time: 4.7771 sec.
# ステップ( 550 )  loss: 6.4747 -- time: 18.3793 sec.
# ステップ( 560 )  loss: 6.4899 -- time: 18.6632 sec.
# ステップ( 570 )  loss: 6.2487 -- time: 18.8086 sec.
# ステップ( 580 )  loss: 6.6571 -- time: 18.2771 sec.
# ステップ( 590 )  loss: 6.8134 -- time: 18.4460 sec.
# ステップ( 600 )  loss: 6.5356 -- time: 18.7054 sec.
# ステップ( 610 )  loss: 6.4016 -- time: 18.5029 sec.
# ステップ( 620 )  loss: 6.7424 -- time: 18.5811 sec.
# ステップ( 630 )  loss: 6.6793 -- time: 18.4627 sec.
# ステップ( 640 )  loss: 6.5607 -- time: 18.5186 sec.
# ステップ( 650 )  loss: 6.5595 -- time: 18.4280 sec.
# ステップ( 660 )  loss: 6.6638 -- time: 18.3321 sec.
# ステップ( 670 )  loss: 7.0656 -- time: 18.4790 sec.
# ステップ( 680 )  loss: 6.7612 -- time: 18.1550 sec.
# ステップ( 690 )  loss: 6.2936 -- time: 18.3477 sec.
# ステップ( 700 )  loss: 6.7230 -- time: 18.4735 sec.
# ステップ( 710 )  loss: 6.0605 -- time: 18.3244 sec.
# ---------------------------------------
# train_loss: 1166.1238 - val_loss(Every 10 epochs): 0.0000
# time:  344.3144 sec.
# ---------------------------------------
# Epoch 5/50
# ---------------------------------------
# ステップ( 720 )  loss: 6.2524 -- time: 6.8075 sec.
# ステップ( 730 )  loss: 6.3215 -- time: 18.4271 sec.
# ステップ( 740 )  loss: 6.1763 -- time: 18.2251 sec.
# ステップ( 750 )  loss: 6.7306 -- time: 18.5660 sec.
# ステップ( 760 )  loss: 6.2893 -- time: 18.5240 sec.
# ステップ( 770 )  loss: 6.5895 -- time: 18.3799 sec.
# ステップ( 780 )  loss: 6.4579 -- time: 18.4093 sec.
# ステップ( 790 )  loss: 6.0414 -- time: 18.5930 sec.
# ステップ( 800 )  loss: 6.6572 -- time: 18.1782 sec.
# ステップ( 810 )  loss: 6.5654 -- time: 18.5271 sec.
# ステップ( 820 )  loss: 6.1457 -- time: 18.4783 sec.
# ステップ( 830 )  loss: 5.9579 -- time: 18.5122 sec.
# ステップ( 840 )  loss: 6.2618 -- time: 18.2263 sec.
# ステップ( 850 )  loss: 6.6523 -- time: 18.1546 sec.
# ステップ( 860 )  loss: 6.0323 -- time: 18.4268 sec.
# ステップ( 870 )  loss: 6.3800 -- time: 18.5701 sec.
# ステップ( 880 )  loss: 6.4585 -- time: 18.3771 sec.
# ステップ( 890 )  loss: 5.5647 -- time: 18.4274 sec.
# ---------------------------------------
# train_loss: 1115.0075 - val_loss(Every 10 epochs): 0.0000
# time:  343.4191 sec.
# ---------------------------------------
# Epoch 6/50
# ---------------------------------------
# ステップ( 900 )  loss: 5.9812 -- time: 8.7111 sec.
# ステップ( 910 )  loss: 6.0567 -- time: 18.5514 sec.
# ステップ( 920 )  loss: 5.7827 -- time: 18.1833 sec.
# ステップ( 930 )  loss: 6.3090 -- time: 18.2419 sec.
# ステップ( 940 )  loss: 6.3955 -- time: 18.2111 sec.
# ステップ( 950 )  loss: 6.0038 -- time: 18.3772 sec.
# ステップ( 960 )  loss: 5.8788 -- time: 18.3017 sec.
# ステップ( 970 )  loss: 5.5225 -- time: 18.5217 sec.
# ステップ( 980 )  loss: 6.3844 -- time: 18.6270 sec.
# ステップ( 990 )  loss: 6.1139 -- time: 18.3265 sec.
# ステップ( 1000 )  loss: 6.1433 -- time: 18.3017 sec.
# ステップ( 1010 )  loss: 6.3454 -- time: 18.2712 sec.
# ステップ( 1020 )  loss: 6.0611 -- time: 18.2054 sec.
# ステップ( 1030 )  loss: 5.7642 -- time: 18.4806 sec.
# ステップ( 1040 )  loss: 5.7635 -- time: 18.3056 sec.
# ステップ( 1050 )  loss: 5.5802 -- time: 18.4868 sec.
# ステップ( 1060 )  loss: 5.1623 -- time: 18.4263 sec.
# ステップ( 1070 )  loss: 5.4668 -- time: 18.2882 sec.
# ---------------------------------------
# train_loss: 1069.6044 - val_loss(Every 10 epochs): 0.0000
# time:  342.6788 sec.
# ---------------------------------------
# Epoch 7/50
# ---------------------------------------
# ステップ( 1080 )  loss: 6.2020 -- time: 10.7252 sec.
# ステップ( 1090 )  loss: 6.0276 -- time: 18.5867 sec.
# ステップ( 1100 )  loss: 6.0255 -- time: 18.1450 sec.
# ステップ( 1110 )  loss: 5.6441 -- time: 18.3573 sec.
# ステップ( 1120 )  loss: 5.9051 -- time: 18.5873 sec.
# ステップ( 1130 )  loss: 5.6422 -- time: 18.4586 sec.
# ステップ( 1140 )  loss: 5.7816 -- time: 18.2472 sec.
# ステップ( 1150 )  loss: 5.7235 -- time: 18.2671 sec.
# ステップ( 1160 )  loss: 5.6052 -- time: 18.5012 sec.
# ステップ( 1170 )  loss: 5.8826 -- time: 18.4338 sec.
# ステップ( 1180 )  loss: 6.0535 -- time: 17.9440 sec.
# ステップ( 1190 )  loss: 5.5899 -- time: 18.4650 sec.
# ステップ( 1200 )  loss: 5.5087 -- time: 18.3315 sec.
# ステップ( 1210 )  loss: 5.3608 -- time: 18.3903 sec.
# ステップ( 1220 )  loss: 5.5933 -- time: 18.5730 sec.
# ステップ( 1230 )  loss: 5.3846 -- time: 18.1550 sec.
# ステップ( 1240 )  loss: 5.7227 -- time: 18.2671 sec.
# ステップ( 1250 )  loss: 5.7024 -- time: 18.2565 sec.
# ---------------------------------------
# train_loss: 1046.2095 - val_loss(Every 10 epochs): 0.0000
# time:  342.6510 sec.
# ---------------------------------------
# Epoch 8/50
# ---------------------------------------
# ステップ( 1260 )  loss: 5.9321 -- time: 12.5144 sec.
# ステップ( 1270 )  loss: 5.6744 -- time: 18.3228 sec.
# ステップ( 1280 )  loss: 5.1951 -- time: 18.3600 sec.
# ステップ( 1290 )  loss: 5.9625 -- time: 18.1480 sec.
# ステップ( 1300 )  loss: 5.4614 -- time: 18.1752 sec.
# ステップ( 1310 )  loss: 5.1979 -- time: 18.6406 sec.
# ステップ( 1320 )  loss: 5.0450 -- time: 18.7000 sec.
# ステップ( 1330 )  loss: 5.2513 -- time: 18.4729 sec.
# ステップ( 1340 )  loss: 5.5662 -- time: 18.3219 sec.
# ステップ( 1350 )  loss: 5.6159 -- time: 18.1712 sec.
# ステップ( 1360 )  loss: 6.0689 -- time: 18.4586 sec.
# ステップ( 1370 )  loss: 6.2425 -- time: 18.4392 sec.
# ステップ( 1380 )  loss: 6.1060 -- time: 18.3602 sec.
# ステップ( 1390 )  loss: 5.8310 -- time: 18.3487 sec.
# ステップ( 1400 )  loss: 6.2532 -- time: 18.5413 sec.
# ステップ( 1410 )  loss: 5.6137 -- time: 18.5260 sec.
# ステップ( 1420 )  loss: 5.8571 -- time: 18.4556 sec.
# ステップ( 1430 )  loss: 6.0351 -- time: 18.2282 sec.
# ---------------------------------------
# train_loss: 1009.8306 - val_loss(Every 10 epochs): 0.0000
# time:  343.2851 sec.
# ---------------------------------------
# Epoch 9/50
# ---------------------------------------
# ステップ( 1440 )  loss: 5.5566 -- time: 14.7578 sec.
# ステップ( 1450 )  loss: 5.4536 -- time: 18.3211 sec.
# ステップ( 1460 )  loss: 5.6778 -- time: 18.5967 sec.
# ステップ( 1470 )  loss: 6.1683 -- time: 18.5757 sec.
# ステップ( 1480 )  loss: 5.7811 -- time: 18.2714 sec.
# ステップ( 1490 )  loss: 6.0983 -- time: 18.6528 sec.
# ステップ( 1500 )  loss: 5.1299 -- time: 18.2942 sec.
# ステップ( 1510 )  loss: 5.5179 -- time: 18.4033 sec.
# ステップ( 1520 )  loss: 5.2810 -- time: 18.2668 sec.
# ステップ( 1530 )  loss: 5.3996 -- time: 18.5082 sec.
# ステップ( 1540 )  loss: 5.5682 -- time: 18.2326 sec.
# ステップ( 1550 )  loss: 5.3210 -- time: 18.5978 sec.
# ステップ( 1560 )  loss: 5.5351 -- time: 18.6099 sec.
# ステップ( 1570 )  loss: 5.3740 -- time: 18.1903 sec.
# ステップ( 1580 )  loss: 5.3813 -- time: 18.6564 sec.
# ステップ( 1590 )  loss: 5.7552 -- time: 18.1947 sec.
# ステップ( 1600 )  loss: 5.6598 -- time: 18.4869 sec.
# ステップ( 1610 )  loss: 6.4163 -- time: 18.4585 sec.
# ---------------------------------------
# train_loss: 981.8495 - val_loss(Every 10 epochs): 0.0000
# time:  344.1885 sec.
# ---------------------------------------
# Epoch 10/50
# ---------------------------------------
# ステップ( 1620 )  loss: 5.2398 -- time: 16.5879 sec.
# ステップ( 1630 )  loss: 5.1657 -- time: 18.4054 sec.
# ステップ( 1640 )  loss: 5.7095 -- time: 18.2966 sec.
# ステップ( 1650 )  loss: 5.4545 -- time: 18.4031 sec.
# ステップ( 1660 )  loss: 5.1623 -- time: 18.3771 sec.
# ステップ( 1670 )  loss: 5.5784 -- time: 18.4043 sec.
# ステップ( 1680 )  loss: 4.6973 -- time: 18.1484 sec.
# ステップ( 1690 )  loss: 5.3747 -- time: 18.4385 sec.
# ステップ( 1700 )  loss: 5.2406 -- time: 18.6406 sec.
# ステップ( 1710 )  loss: 4.9559 -- time: 18.4984 sec.
# ステップ( 1720 )  loss: 4.9019 -- time: 18.4133 sec.
# ステップ( 1730 )  loss: 5.5646 -- time: 18.2737 sec.
# ステップ( 1740 )  loss: 5.4301 -- time: 18.3051 sec.
# ステップ( 1750 )  loss: 5.2321 -- time: 18.2069 sec.
# ステップ( 1760 )  loss: 4.7360 -- time: 18.5046 sec.
# ステップ( 1770 )  loss: 5.2185 -- time: 18.2767 sec.
# ステップ( 1780 )  loss: 5.1591 -- time: 18.4259 sec.
# ステップ( 1790 )  loss: 6.2215 -- time: 17.9494 sec.
# ---------------------------------------
# （validation）
# ---------------------------------------
# train_loss: 955.9168 - val_loss(Every 10 epochs): 968.6886
# time:  2813.3587 sec.
# --saved weights--
# ---------------------------------------
# Epoch 11/50
# ---------------------------------------
# ステップ( 1800 )  loss: 5.6969 -- time: 18.0175 sec.
# ステップ( 1810 )  loss: 4.8096 -- time: 18.8083 sec.
# ステップ( 1820 )  loss: 5.0752 -- time: 18.1788 sec.
# ステップ( 1830 )  loss: 5.5861 -- time: 18.3329 sec.
# ステップ( 1840 )  loss: 5.4719 -- time: 18.2963 sec.
# ステップ( 1850 )  loss: 4.9597 -- time: 18.4485 sec.
# ステップ( 1860 )  loss: 5.0241 -- time: 18.0813 sec.
# ステップ( 1870 )  loss: 5.1301 -- time: 18.1494 sec.
# ステップ( 1880 )  loss: 5.5735 -- time: 18.4360 sec.
# ステップ( 1890 )  loss: 5.5296 -- time: 18.6491 sec.
# ステップ( 1900 )  loss: 4.9461 -- time: 18.3060 sec.
# ステップ( 1910 )  loss: 5.0950 -- time: 18.6908 sec.
# ステップ( 1920 )  loss: 5.4209 -- time: 18.8269 sec.
# ステップ( 1930 )  loss: 5.4504 -- time: 18.5244 sec.
# ステップ( 1940 )  loss: 5.4930 -- time: 18.4894 sec.
# ステップ( 1950 )  loss: 4.8908 -- time: 18.5029 sec.
# ステップ( 1960 )  loss: 5.2921 -- time: 18.2628 sec.
# ---------------------------------------
# train_loss: 936.5935 - val_loss(Every 10 epochs): 0.0000
# time:  343.5561 sec.
# ---------------------------------------
# Epoch 12/50
# ---------------------------------------
# ステップ( 1970 )  loss: 5.3222 -- time: 1.3311 sec.
# ステップ( 1980 )  loss: 5.1625 -- time: 18.4536 sec.
# ステップ( 1990 )  loss: 4.8719 -- time: 18.4835 sec.
# ステップ( 2000 )  loss: 5.2233 -- time: 18.4759 sec.
# ステップ( 2010 )  loss: 5.4018 -- time: 18.4649 sec.
# ステップ( 2020 )  loss: 5.6114 -- time: 18.8727 sec.
# ステップ( 2030 )  loss: 5.0870 -- time: 18.3718 sec.
# ステップ( 2040 )  loss: 4.8856 -- time: 18.6115 sec.
# ステップ( 2050 )  loss: 5.0543 -- time: 18.7222 sec.
# ステップ( 2060 )  loss: 4.5682 -- time: 18.5292 sec.
# ステップ( 2070 )  loss: 4.7173 -- time: 18.7651 sec.
# ステップ( 2080 )  loss: 5.7755 -- time: 18.7473 sec.
# ステップ( 2090 )  loss: 5.6052 -- time: 18.3708 sec.
# ステップ( 2100 )  loss: 5.4211 -- time: 18.8837 sec.
# ステップ( 2110 )  loss: 4.9496 -- time: 18.5439 sec.
# ステップ( 2120 )  loss: 4.1705 -- time: 18.4913 sec.
# ステップ( 2130 )  loss: 4.6238 -- time: 18.4677 sec.
# ステップ( 2140 )  loss: 5.0565 -- time: 18.3030 sec.
# ---------------------------------------
# train_loss: 916.4910 - val_loss(Every 10 epochs): 0.0000
# time:  346.2474 sec.
# ---------------------------------------
# Epoch 13/50
# ---------------------------------------
# ステップ( 2150 )  loss: 5.2179 -- time: 3.0743 sec.
# ステップ( 2160 )  loss: 4.8144 -- time: 18.4866 sec.
# ステップ( 2170 )  loss: 4.9658 -- time: 18.6542 sec.
# ステップ( 2180 )  loss: 4.6030 -- time: 18.4548 sec.
# ステップ( 2190 )  loss: 4.6575 -- time: 18.7808 sec.
# ステップ( 2200 )  loss: 5.4530 -- time: 18.8445 sec.
# ステップ( 2210 )  loss: 5.3448 -- time: 18.4666 sec.
# ステップ( 2220 )  loss: 5.0464 -- time: 18.9529 sec.
# ステップ( 2230 )  loss: 5.5581 -- time: 18.6620 sec.
# ステップ( 2240 )  loss: 5.0179 -- time: 18.1704 sec.
# ステップ( 2250 )  loss: 4.5873 -- time: 18.3897 sec.
# ステップ( 2260 )  loss: 5.0183 -- time: 18.7490 sec.
# ステップ( 2270 )  loss: 4.8812 -- time: 18.8967 sec.
# ステップ( 2280 )  loss: 5.1950 -- time: 18.7892 sec.
# ステップ( 2290 )  loss: 5.2396 -- time: 18.8442 sec.
# ステップ( 2300 )  loss: 4.4958 -- time: 18.2996 sec.
# ステップ( 2310 )  loss: 5.4795 -- time: 18.4139 sec.
# ステップ( 2320 )  loss: 5.1061 -- time: 18.6730 sec.
# ---------------------------------------
# train_loss: 900.2287 - val_loss(Every 10 epochs): 0.0000
# time:  347.3379 sec.
# ---------------------------------------
# Epoch 14/50
# ---------------------------------------
# ステップ( 2330 )  loss: 4.6781 -- time: 4.9686 sec.
# ステップ( 2340 )  loss: 4.7023 -- time: 18.7558 sec.
# ステップ( 2350 )  loss: 4.5920 -- time: 18.6681 sec.
# ステップ( 2360 )  loss: 5.2537 -- time: 18.7610 sec.
# ステップ( 2370 )  loss: 4.8139 -- time: 18.3861 sec.
# ステップ( 2380 )  loss: 5.1684 -- time: 18.3711 sec.
# ステップ( 2390 )  loss: 5.0710 -- time: 18.3922 sec.
# ステップ( 2400 )  loss: 4.9391 -- time: 18.3043 sec.
# ステップ( 2410 )  loss: 4.8603 -- time: 18.1957 sec.
# ステップ( 2420 )  loss: 5.2532 -- time: 18.3078 sec.
# ステップ( 2430 )  loss: 4.6823 -- time: 18.3776 sec.
# ステップ( 2440 )  loss: 4.3077 -- time: 18.4059 sec.
# ステップ( 2450 )  loss: 4.6127 -- time: 18.3878 sec.
# ステップ( 2460 )  loss: 4.6996 -- time: 18.4810 sec.
# ステップ( 2470 )  loss: 5.1136 -- time: 18.5575 sec.
# ステップ( 2480 )  loss: 5.1979 -- time: 18.4545 sec.
# ステップ( 2490 )  loss: 4.7144 -- time: 18.6141 sec.
# ステップ( 2500 )  loss: 4.8760 -- time: 18.6310 sec.
# ---------------------------------------
# train_loss: 877.8062 - val_loss(Every 10 epochs): 0.0000
# time:  344.5452 sec.
# ---------------------------------------
# Epoch 15/50
# ---------------------------------------
# ステップ( 2510 )  loss: 5.2604 -- time: 6.7464 sec.
# ステップ( 2520 )  loss: 4.5261 -- time: 18.3385 sec.
# ステップ( 2530 )  loss: 4.9830 -- time: 18.6773 sec.
# ステップ( 2540 )  loss: 4.4572 -- time: 18.5178 sec.
# ステップ( 2550 )  loss: 4.8273 -- time: 18.8080 sec.
# ステップ( 2560 )  loss: 4.6022 -- time: 18.1154 sec.
# ステップ( 2570 )  loss: 4.5113 -- time: 18.2632 sec.
# ステップ( 2580 )  loss: 4.6768 -- time: 18.4810 sec.
# ステップ( 2590 )  loss: 4.7144 -- time: 18.2490 sec.
# ステップ( 2600 )  loss: 5.1047 -- time: 18.6572 sec.
# ステップ( 2610 )  loss: 4.4873 -- time: 18.2474 sec.
# ステップ( 2620 )  loss: 4.5238 -- time: 18.3319 sec.
# ステップ( 2630 )  loss: 4.7078 -- time: 18.4715 sec.
# ステップ( 2640 )  loss: 5.0869 -- time: 18.3242 sec.
# ステップ( 2650 )  loss: 4.9937 -- time: 18.4781 sec.
# ステップ( 2660 )  loss: 4.4142 -- time: 18.4755 sec.
# ステップ( 2670 )  loss: 4.6385 -- time: 18.4988 sec.
# ステップ( 2680 )  loss: 4.9218 -- time: 18.4360 sec.
# ---------------------------------------
# train_loss: 862.2269 - val_loss(Every 10 epochs): 0.0000
# time:  343.8299 sec.
# ---------------------------------------
# Epoch 16/50
# ---------------------------------------
# ステップ( 2690 )  loss: 5.0320 -- time: 8.8355 sec.
# ステップ( 2700 )  loss: 5.0196 -- time: 18.6699 sec.
# ステップ( 2710 )  loss: 4.5788 -- time: 18.4759 sec.
# ステップ( 2720 )  loss: 4.7339 -- time: 18.3070 sec.
# ステップ( 2730 )  loss: 4.5459 -- time: 18.3115 sec.
# ステップ( 2740 )  loss: 4.5809 -- time: 18.5870 sec.
# ステップ( 2750 )  loss: 5.0652 -- time: 18.5324 sec.
# ステップ( 2760 )  loss: 5.1082 -- time: 18.3757 sec.
# ステップ( 2770 )  loss: 4.7902 -- time: 18.3979 sec.
# ステップ( 2780 )  loss: 4.6093 -- time: 18.4576 sec.
# ステップ( 2790 )  loss: 5.0151 -- time: 18.4275 sec.
# ステップ( 2800 )  loss: 4.4203 -- time: 18.5562 sec.
# ステップ( 2810 )  loss: 4.4610 -- time: 18.3252 sec.
# ステップ( 2820 )  loss: 5.1419 -- time: 18.5085 sec.
# ステップ( 2830 )  loss: 4.4255 -- time: 18.3591 sec.
# ステップ( 2840 )  loss: 5.1655 -- time: 18.2127 sec.
# ステップ( 2850 )  loss: 5.0768 -- time: 18.3548 sec.
# ステップ( 2860 )  loss: 4.2808 -- time: 18.5906 sec.
# ---------------------------------------
# train_loss: 848.9459 - val_loss(Every 10 epochs): 0.0000
# time:  344.2133 sec.
# ---------------------------------------
# Epoch 17/50
# ---------------------------------------
# ステップ( 2870 )  loss: 4.4599 -- time: 10.8816 sec.
# ステップ( 2880 )  loss: 4.2777 -- time: 18.3744 sec.
# ステップ( 2890 )  loss: 5.4683 -- time: 17.9317 sec.
# ステップ( 2900 )  loss: 5.0676 -- time: 18.6338 sec.
# ステップ( 2910 )  loss: 4.5188 -- time: 18.5895 sec.
# ステップ( 2920 )  loss: 4.6590 -- time: 18.3237 sec.
# ステップ( 2930 )  loss: 4.7427 -- time: 18.3317 sec.
# ステップ( 2940 )  loss: 4.5707 -- time: 18.4893 sec.
# ステップ( 2950 )  loss: 4.5807 -- time: 18.5181 sec.
# ステップ( 2960 )  loss: 4.5586 -- time: 18.4462 sec.
# ステップ( 2970 )  loss: 4.7703 -- time: 18.2194 sec.
# ステップ( 2980 )  loss: 4.7142 -- time: 18.3094 sec.
# ステップ( 2990 )  loss: 4.9834 -- time: 18.4554 sec.
# ステップ( 3000 )  loss: 4.6305 -- time: 18.1302 sec.
# ステップ( 3010 )  loss: 4.9619 -- time: 18.6082 sec.
# ステップ( 3020 )  loss: 4.2148 -- time: 18.7349 sec.
# ステップ( 3030 )  loss: 4.6607 -- time: 18.5631 sec.
# ステップ( 3040 )  loss: 4.4497 -- time: 18.2914 sec.
# ---------------------------------------
# train_loss: 841.9700 - val_loss(Every 10 epochs): 0.0000
# time:  343.7936 sec.
# ---------------------------------------
# Epoch 18/50
# ---------------------------------------
# ステップ( 3050 )  loss: 4.4237 -- time: 12.6474 sec.
# ステップ( 3060 )  loss: 4.3277 -- time: 18.4134 sec.
# ステップ( 3070 )  loss: 4.7030 -- time: 18.1794 sec.
# ステップ( 3080 )  loss: 4.5374 -- time: 18.6141 sec.
# ステップ( 3090 )  loss: 4.9878 -- time: 18.3868 sec.
# ステップ( 3100 )  loss: 4.8651 -- time: 18.3321 sec.
# ステップ( 3110 )  loss: 4.9127 -- time: 18.4244 sec.
# ステップ( 3120 )  loss: 4.5621 -- time: 18.4101 sec.
# ステップ( 3130 )  loss: 4.6689 -- time: 18.7017 sec.
# ステップ( 3140 )  loss: 5.1744 -- time: 18.2241 sec.
# ステップ( 3150 )  loss: 4.0222 -- time: 18.1400 sec.
# ステップ( 3160 )  loss: 4.8970 -- time: 18.6390 sec.
# ステップ( 3170 )  loss: 4.2006 -- time: 18.5352 sec.
# ステップ( 3180 )  loss: 4.6619 -- time: 18.5412 sec.
# ステップ( 3190 )  loss: 4.7142 -- time: 18.6956 sec.
# ステップ( 3200 )  loss: 4.9394 -- time: 18.4180 sec.
# ステップ( 3210 )  loss: 4.4420 -- time: 18.3859 sec.
# ステップ( 3220 )  loss: 4.1657 -- time: 18.5780 sec.
# ---------------------------------------
# train_loss: 823.4361 - val_loss(Every 10 epochs): 0.0000
# time:  344.2394 sec.
# ---------------------------------------
# Epoch 19/50
# ---------------------------------------
# ステップ( 3230 )  loss: 4.4805 -- time: 14.8937 sec.
# ステップ( 3240 )  loss: 5.0122 -- time: 18.4942 sec.
# ステップ( 3250 )  loss: 4.4936 -- time: 18.9533 sec.
# ステップ( 3260 )  loss: 4.2172 -- time: 18.4953 sec.
# ステップ( 3270 )  loss: 4.5904 -- time: 18.3038 sec.
# ステップ( 3280 )  loss: 4.4054 -- time: 18.5197 sec.
# ステップ( 3290 )  loss: 4.9887 -- time: 18.5758 sec.
# ステップ( 3300 )  loss: 4.4072 -- time: 18.4467 sec.
# ステップ( 3310 )  loss: 4.9708 -- time: 18.3412 sec.
# ステップ( 3320 )  loss: 4.7272 -- time: 18.2936 sec.
# ステップ( 3330 )  loss: 4.6676 -- time: 18.6033 sec.
# ステップ( 3340 )  loss: 5.0141 -- time: 18.3314 sec.
# ステップ( 3350 )  loss: 4.6988 -- time: 18.2531 sec.
# ステップ( 3360 )  loss: 4.6494 -- time: 18.8195 sec.
# ステップ( 3370 )  loss: 4.7713 -- time: 18.4869 sec.
# ステップ( 3380 )  loss: 4.3137 -- time: 18.4054 sec.
# ステップ( 3390 )  loss: 4.3876 -- time: 18.3461 sec.
# ステップ( 3400 )  loss: 4.0814 -- time: 18.5139 sec.
# ---------------------------------------
# train_loss: 809.8945 - val_loss(Every 10 epochs): 0.0000
# time:  345.0948 sec.
# ---------------------------------------
# Epoch 20/50
# ---------------------------------------
# ステップ( 3410 )  loss: 4.5512 -- time: 16.5532 sec.
# ステップ( 3420 )  loss: 4.2097 -- time: 18.2689 sec.
# ステップ( 3430 )  loss: 4.0816 -- time: 18.2285 sec.
# ステップ( 3440 )  loss: 4.6561 -- time: 18.4068 sec.
# ステップ( 3450 )  loss: 4.5869 -- time: 18.4578 sec.
# ステップ( 3460 )  loss: 4.2471 -- time: 18.4118 sec.
# ステップ( 3470 )  loss: 4.0585 -- time: 18.4824 sec.
# ステップ( 3480 )  loss: 4.6694 -- time: 18.2482 sec.
# ステップ( 3490 )  loss: 4.3383 -- time: 18.4114 sec.
# ステップ( 3500 )  loss: 4.4955 -- time: 18.3248 sec.
# ステップ( 3510 )  loss: 4.8420 -- time: 18.3281 sec.
# ステップ( 3520 )  loss: 4.4274 -- time: 18.4739 sec.
# ステップ( 3530 )  loss: 4.7264 -- time: 18.2045 sec.
# ステップ( 3540 )  loss: 4.1570 -- time: 18.5301 sec.
# ステップ( 3550 )  loss: 4.1941 -- time: 18.2205 sec.
# ステップ( 3560 )  loss: 4.4632 -- time: 18.3632 sec.
# ステップ( 3570 )  loss: 4.3076 -- time: 18.2704 sec.
# ステップ( 3580 )  loss: 4.5851 -- time: 18.1800 sec.
# ---------------------------------------
# （validation）
# ---------------------------------------
# train_loss: 794.8978 - val_loss(Every 10 epochs): 821.8536
# time:  484.1265 sec.
# --saved weights--
# ---------------------------------------
# Epoch 21/50
# ---------------------------------------
# ステップ( 3590 )  loss: 4.1529 -- time: 18.3025 sec.
# ステップ( 3600 )  loss: 4.3946 -- time: 18.2656 sec.
# ステップ( 3610 )  loss: 3.7479 -- time: 18.4845 sec.
# ステップ( 3620 )  loss: 4.5268 -- time: 18.9278 sec.
# ステップ( 3630 )  loss: 4.7342 -- time: 18.1822 sec.
# ステップ( 3640 )  loss: 4.0976 -- time: 18.3833 sec.
# ステップ( 3650 )  loss: 3.9299 -- time: 18.1078 sec.
# ステップ( 3660 )  loss: 4.8443 -- time: 18.3830 sec.
# ステップ( 3670 )  loss: 4.3382 -- time: 18.4942 sec.
# ステップ( 3680 )  loss: 3.7164 -- time: 18.3768 sec.
# ステップ( 3690 )  loss: 4.3957 -- time: 18.5016 sec.
# ステップ( 3700 )  loss: 4.1783 -- time: 18.3192 sec.
# ステップ( 3710 )  loss: 4.7624 -- time: 18.4758 sec.
# ステップ( 3720 )  loss: 4.6603 -- time: 18.1430 sec.
# ステップ( 3730 )  loss: 4.8055 -- time: 18.2595 sec.
# ステップ( 3740 )  loss: 4.2252 -- time: 18.3919 sec.
# ステップ( 3750 )  loss: 4.8269 -- time: 18.1845 sec.
# ---------------------------------------
# train_loss: 791.7600 - val_loss(Every 10 epochs): 0.0000
# time:  342.7684 sec.
# ---------------------------------------
# Epoch 22/50
# ---------------------------------------
# ステップ( 3760 )  loss: 4.2318 -- time: 1.1247 sec.
# ステップ( 3770 )  loss: 4.5414 -- time: 18.4739 sec.
# ステップ( 3780 )  loss: 4.4754 -- time: 18.4830 sec.
# ステップ( 3790 )  loss: 4.4507 -- time: 18.4059 sec.
# ステップ( 3800 )  loss: 3.8464 -- time: 18.2967 sec.
# ステップ( 3810 )  loss: 4.3314 -- time: 18.2981 sec.
# ステップ( 3820 )  loss: 4.3162 -- time: 18.3661 sec.
# ステップ( 3830 )  loss: 4.0620 -- time: 18.3918 sec.
# ステップ( 3840 )  loss: 4.5386 -- time: 18.2509 sec.
# ステップ( 3850 )  loss: 4.2447 -- time: 18.2183 sec.
# ステップ( 3860 )  loss: 4.0539 -- time: 18.1834 sec.
# ステップ( 3870 )  loss: 4.5525 -- time: 18.2822 sec.
# ステップ( 3880 )  loss: 4.2588 -- time: 18.4155 sec.
# ステップ( 3890 )  loss: 4.4386 -- time: 18.2978 sec.
# ステップ( 3900 )  loss: 4.4549 -- time: 18.4199 sec.
# ステップ( 3910 )  loss: 4.5940 -- time: 18.2259 sec.
# ステップ( 3920 )  loss: 4.2319 -- time: 18.3510 sec.
# ステップ( 3930 )  loss: 4.3659 -- time: 18.5947 sec.
# ---------------------------------------
# train_loss: 771.9881 - val_loss(Every 10 epochs): 0.0000
# time:  342.6545 sec.
# ---------------------------------------
# Epoch 23/50
# ---------------------------------------
# ステップ( 3940 )  loss: 4.6271 -- time: 3.0282 sec.
# ステップ( 3950 )  loss: 4.3249 -- time: 18.7676 sec.
# ステップ( 3960 )  loss: 4.0859 -- time: 18.3537 sec.
# ステップ( 3970 )  loss: 4.0227 -- time: 18.4121 sec.
# ステップ( 3980 )  loss: 4.1241 -- time: 18.1603 sec.
# ステップ( 3990 )  loss: 4.0511 -- time: 18.1406 sec.
# ステップ( 4000 )  loss: 4.4818 -- time: 18.2738 sec.
# ステップ( 4010 )  loss: 4.1823 -- time: 18.5404 sec.
# ステップ( 4020 )  loss: 4.6363 -- time: 18.1388 sec.
# ステップ( 4030 )  loss: 4.2348 -- time: 18.3131 sec.
# ステップ( 4040 )  loss: 4.3751 -- time: 18.2827 sec.
# ステップ( 4050 )  loss: 4.7249 -- time: 18.2084 sec.
# ステップ( 4060 )  loss: 4.1793 -- time: 18.5610 sec.
# ステップ( 4070 )  loss: 3.9156 -- time: 18.3896 sec.
# ステップ( 4080 )  loss: 4.6597 -- time: 18.4344 sec.
# ステップ( 4090 )  loss: 4.6609 -- time: 18.5965 sec.
# ステップ( 4100 )  loss: 4.2525 -- time: 18.3299 sec.
# ステップ( 4110 )  loss: 4.5015 -- time: 18.3858 sec.
# ---------------------------------------
# train_loss: 770.4926 - val_loss(Every 10 epochs): 0.0000
# time:  342.9059 sec.
# ---------------------------------------
# Epoch 24/50
# ---------------------------------------
# ステップ( 4120 )  loss: 4.4214 -- time: 4.8284 sec.
# ステップ( 4130 )  loss: 3.6243 -- time: 18.5909 sec.
# ステップ( 4140 )  loss: 4.6143 -- time: 18.5312 sec.
# ステップ( 4150 )  loss: 4.4114 -- time: 18.3475 sec.
# ステップ( 4160 )  loss: 3.5188 -- time: 18.5428 sec.
# ステップ( 4170 )  loss: 4.5659 -- time: 18.5099 sec.
# ステップ( 4180 )  loss: 4.2879 -- time: 18.3611 sec.
# ステップ( 4190 )  loss: 4.2575 -- time: 18.4927 sec.
# ステップ( 4200 )  loss: 3.6149 -- time: 18.2906 sec.
# ステップ( 4210 )  loss: 4.4499 -- time: 18.2664 sec.
# ステップ( 4220 )  loss: 3.8196 -- time: 18.7182 sec.
# ステップ( 4230 )  loss: 4.0565 -- time: 18.0718 sec.
# ステップ( 4240 )  loss: 4.2139 -- time: 18.2793 sec.
# ステップ( 4250 )  loss: 3.9590 -- time: 18.4526 sec.
# ステップ( 4260 )  loss: 4.7616 -- time: 18.5942 sec.
# ステップ( 4270 )  loss: 4.0467 -- time: 18.3170 sec.
# ステップ( 4280 )  loss: 4.5703 -- time: 18.3906 sec.
# ステップ( 4290 )  loss: 3.8407 -- time: 18.7132 sec.
# ---------------------------------------
# train_loss: 759.5427 - val_loss(Every 10 epochs): 0.0000
# time:  343.9292 sec.
# ---------------------------------------
# Epoch 25/50
# ---------------------------------------
# ステップ( 4300 )  loss: 4.5694 -- time: 6.7392 sec.
# ステップ( 4310 )  loss: 4.5185 -- time: 18.5318 sec.
# ステップ( 4320 )  loss: 3.8224 -- time: 18.2532 sec.
# ステップ( 4330 )  loss: 4.0630 -- time: 18.5046 sec.
# ステップ( 4340 )  loss: 3.6933 -- time: 18.2564 sec.
# ステップ( 4350 )  loss: 3.8765 -- time: 18.2366 sec.
# ステップ( 4360 )  loss: 4.4288 -- time: 18.3393 sec.
# ステップ( 4370 )  loss: 4.4175 -- time: 18.2965 sec.
# ステップ( 4380 )  loss: 3.6823 -- time: 18.2398 sec.
# ステップ( 4390 )  loss: 4.6577 -- time: 18.2678 sec.
# ステップ( 4400 )  loss: 4.6738 -- time: 18.3157 sec.
# ステップ( 4410 )  loss: 4.0424 -- time: 18.5014 sec.
# ステップ( 4420 )  loss: 4.3894 -- time: 18.6453 sec.
# ステップ( 4430 )  loss: 4.4980 -- time: 18.5503 sec.
# ステップ( 4440 )  loss: 3.6465 -- time: 18.1089 sec.
# ステップ( 4450 )  loss: 4.3308 -- time: 18.1098 sec.
# ステップ( 4460 )  loss: 3.8003 -- time: 18.5542 sec.
# ステップ( 4470 )  loss: 3.9406 -- time: 18.3152 sec.
# ---------------------------------------
# train_loss: 752.6682 - val_loss(Every 10 epochs): 0.0000
# time:  342.5714 sec.
# ---------------------------------------
# Epoch 26/50
# ---------------------------------------
# ステップ( 4480 )  loss: 4.0638 -- time: 8.8651 sec.
# ステップ( 4490 )  loss: 4.1147 -- time: 18.5578 sec.
# ステップ( 4500 )  loss: 4.5203 -- time: 18.2147 sec.
# ステップ( 4510 )  loss: 4.3346 -- time: 18.5027 sec.
# ステップ( 4520 )  loss: 4.1738 -- time: 18.5850 sec.
# ステップ( 4530 )  loss: 3.8560 -- time: 18.4520 sec.
# ステップ( 4540 )  loss: 4.1654 -- time: 18.4893 sec.
# ステップ( 4550 )  loss: 4.4522 -- time: 18.5792 sec.
# ステップ( 4560 )  loss: 4.2798 -- time: 18.6494 sec.
# ステップ( 4570 )  loss: 4.3012 -- time: 18.2142 sec.
# ステップ( 4580 )  loss: 3.6751 -- time: 18.3457 sec.
# ステップ( 4590 )  loss: 3.7697 -- time: 18.2964 sec.
# ステップ( 4600 )  loss: 4.2860 -- time: 18.6605 sec.
# ステップ( 4610 )  loss: 3.8330 -- time: 18.3363 sec.
# ステップ( 4620 )  loss: 4.4676 -- time: 18.3859 sec.
# ステップ( 4630 )  loss: 4.4521 -- time: 18.1616 sec.
# ステップ( 4640 )  loss: 3.9506 -- time: 18.4479 sec.
# ステップ( 4650 )  loss: 3.8796 -- time: 18.2467 sec.
# ---------------------------------------
# train_loss: 739.6368 - val_loss(Every 10 epochs): 0.0000
# time:  343.9865 sec.
# ---------------------------------------
# Epoch 27/50
# ---------------------------------------
# ステップ( 4660 )  loss: 4.0974 -- time: 10.6813 sec.
# ステップ( 4670 )  loss: 4.1487 -- time: 18.2039 sec.
# ステップ( 4680 )  loss: 3.9554 -- time: 18.4136 sec.
# ステップ( 4690 )  loss: 3.5039 -- time: 18.2919 sec.
# ステップ( 4700 )  loss: 3.9887 -- time: 18.3169 sec.
# ステップ( 4710 )  loss: 4.2049 -- time: 18.4447 sec.
# ステップ( 4720 )  loss: 4.3395 -- time: 18.4030 sec.
# ステップ( 4730 )  loss: 3.8389 -- time: 18.2268 sec.
# ステップ( 4740 )  loss: 4.0810 -- time: 18.3269 sec.
# ステップ( 4750 )  loss: 4.2603 -- time: 18.2365 sec.
# ステップ( 4760 )  loss: 3.8716 -- time: 18.0954 sec.
# ステップ( 4770 )  loss: 3.7375 -- time: 18.4611 sec.
# ステップ( 4780 )  loss: 3.9795 -- time: 18.5506 sec.
# ステップ( 4790 )  loss: 4.4244 -- time: 18.2399 sec.
# ステップ( 4800 )  loss: 4.0842 -- time: 18.4000 sec.
# ステップ( 4810 )  loss: 3.7735 -- time: 18.4915 sec.
# ステップ( 4820 )  loss: 4.0813 -- time: 18.5392 sec.
# ステップ( 4830 )  loss: 3.9442 -- time: 18.5114 sec.
# ---------------------------------------
# train_loss: 733.4899 - val_loss(Every 10 epochs): 0.0000
# time:  342.6070 sec.
# ---------------------------------------
# Epoch 28/50
# ---------------------------------------
# ステップ( 4840 )  loss: 4.1124 -- time: 12.7682 sec.
# ステップ( 4850 )  loss: 4.0666 -- time: 18.3377 sec.
# ステップ( 4860 )  loss: 3.9640 -- time: 18.4852 sec.
# ステップ( 4870 )  loss: 4.0261 -- time: 18.2734 sec.
# ステップ( 4880 )  loss: 4.6128 -- time: 18.4025 sec.
# ステップ( 4890 )  loss: 3.7587 -- time: 18.3023 sec.
# ステップ( 4900 )  loss: 4.1762 -- time: 18.1602 sec.
# ステップ( 4910 )  loss: 4.2724 -- time: 18.1109 sec.
# ステップ( 4920 )  loss: 4.3082 -- time: 18.1510 sec.
# ステップ( 4930 )  loss: 3.8667 -- time: 18.5404 sec.
# ステップ( 4940 )  loss: 4.7461 -- time: 18.4646 sec.
# ステップ( 4950 )  loss: 4.4255 -- time: 18.5570 sec.
# ステップ( 4960 )  loss: 3.8553 -- time: 18.2503 sec.
# ステップ( 4970 )  loss: 3.8664 -- time: 18.1163 sec.
# ステップ( 4980 )  loss: 4.2833 -- time: 18.4089 sec.
# ステップ( 4990 )  loss: 4.3681 -- time: 18.4058 sec.
# ステップ( 5000 )  loss: 4.4323 -- time: 18.3940 sec.
# ステップ( 5010 )  loss: 4.0004 -- time: 18.1724 sec.
# ---------------------------------------
# train_loss: 728.2541 - val_loss(Every 10 epochs): 0.0000
# time:  342.3620 sec.
# ---------------------------------------
# Epoch 29/50
# ---------------------------------------
# ステップ( 5020 )  loss: 4.0828 -- time: 14.2918 sec.
# ステップ( 5030 )  loss: 4.4272 -- time: 18.1921 sec.
# ステップ( 5040 )  loss: 4.5051 -- time: 18.4871 sec.
# ステップ( 5050 )  loss: 4.2990 -- time: 18.3329 sec.
# ステップ( 5060 )  loss: 4.3541 -- time: 18.2392 sec.
# ステップ( 5070 )  loss: 3.6979 -- time: 18.4531 sec.
# ステップ( 5080 )  loss: 3.8650 -- time: 18.4900 sec.
# ステップ( 5090 )  loss: 3.9989 -- time: 18.3690 sec.
# ステップ( 5100 )  loss: 4.3393 -- time: 18.4816 sec.
# ステップ( 5110 )  loss: 4.3352 -- time: 18.3855 sec.
# ステップ( 5120 )  loss: 4.2040 -- time: 18.1836 sec.
# ステップ( 5130 )  loss: 3.8842 -- time: 18.4987 sec.
# ステップ( 5140 )  loss: 3.9735 -- time: 18.4885 sec.
# ステップ( 5150 )  loss: 3.9502 -- time: 18.3058 sec.
# ステップ( 5160 )  loss: 3.8796 -- time: 18.4171 sec.
# ステップ( 5170 )  loss: 3.7546 -- time: 18.5152 sec.
# ステップ( 5180 )  loss: 4.0619 -- time: 18.4877 sec.
# ステップ( 5190 )  loss: 4.0784 -- time: 18.2663 sec.
# ---------------------------------------
# train_loss: 718.6030 - val_loss(Every 10 epochs): 0.0000
# time:  342.9919 sec.
# ---------------------------------------
# Epoch 30/50
# ---------------------------------------
# ステップ( 5200 )  loss: 4.2113 -- time: 16.5998 sec.
# ステップ( 5210 )  loss: 3.7917 -- time: 18.4560 sec.
# ステップ( 5220 )  loss: 4.5893 -- time: 18.2172 sec.
# ステップ( 5230 )  loss: 3.8521 -- time: 18.3605 sec.
# ステップ( 5240 )  loss: 3.9216 -- time: 18.8043 sec.
# ステップ( 5250 )  loss: 4.1038 -- time: 18.4225 sec.
# ステップ( 5260 )  loss: 4.1845 -- time: 18.4302 sec.
# ステップ( 5270 )  loss: 4.2218 -- time: 18.1530 sec.
# ステップ( 5280 )  loss: 3.4791 -- time: 18.4379 sec.
# ステップ( 5290 )  loss: 3.7315 -- time: 18.2497 sec.
# ステップ( 5300 )  loss: 4.1615 -- time: 18.3562 sec.
# ステップ( 5310 )  loss: 3.8657 -- time: 18.2782 sec.
# ステップ( 5320 )  loss: 4.0589 -- time: 18.1799 sec.
# ステップ( 5330 )  loss: 3.7735 -- time: 18.4320 sec.
# ステップ( 5340 )  loss: 4.0999 -- time: 18.3233 sec.
# ステップ( 5350 )  loss: 4.2440 -- time: 18.3885 sec.
# ステップ( 5360 )  loss: 4.3424 -- time: 18.2763 sec.
# ステップ( 5370 )  loss: 3.7907 -- time: 18.1102 sec.
# ---------------------------------------
# （validation）
# ---------------------------------------
# train_loss: 720.3262 - val_loss(Every 10 epochs): 750.4115
# time:  484.4280 sec.
# --saved weights--
# ---------------------------------------
# Epoch 31/50
# ---------------------------------------
# ステップ( 5380 )  loss: 3.8209 -- time: 18.5184 sec.
# ステップ( 5390 )  loss: 4.2688 -- time: 18.4027 sec.
# ステップ( 5400 )  loss: 3.6204 -- time: 18.0579 sec.
# ステップ( 5410 )  loss: 3.9303 -- time: 18.1252 sec.
# ステップ( 5420 )  loss: 3.7776 -- time: 18.2276 sec.
# ステップ( 5430 )  loss: 4.2320 -- time: 18.2372 sec.
# ステップ( 5440 )  loss: 4.0142 -- time: 18.2808 sec.
# ステップ( 5450 )  loss: 4.5836 -- time: 18.3968 sec.
# ステップ( 5460 )  loss: 4.1548 -- time: 18.6717 sec.
# ステップ( 5470 )  loss: 3.7297 -- time: 18.2301 sec.
# ステップ( 5480 )  loss: 3.8848 -- time: 18.2696 sec.
# ステップ( 5490 )  loss: 3.5755 -- time: 18.4511 sec.
# ステップ( 5500 )  loss: 3.6661 -- time: 18.5117 sec.
# ステップ( 5510 )  loss: 4.0228 -- time: 18.5329 sec.
# ステップ( 5520 )  loss: 3.6821 -- time: 18.4987 sec.
# ステップ( 5530 )  loss: 4.1618 -- time: 18.3666 sec.
# ステップ( 5540 )  loss: 4.0243 -- time: 18.2492 sec.
# ---------------------------------------
# train_loss: 707.4258 - val_loss(Every 10 epochs): 0.0000
# time:  342.6571 sec.
# ---------------------------------------
# Epoch 32/50
# ---------------------------------------
# ステップ( 5550 )  loss: 3.9065 -- time: 1.0849 sec.
# ステップ( 5560 )  loss: 4.3471 -- time: 18.4108 sec.
# ステップ( 5570 )  loss: 3.9598 -- time: 18.2011 sec.
# ステップ( 5580 )  loss: 4.1784 -- time: 18.5053 sec.
# ステップ( 5590 )  loss: 3.7241 -- time: 18.4178 sec.
# ステップ( 5600 )  loss: 4.0253 -- time: 18.2885 sec.
# ステップ( 5610 )  loss: 3.7728 -- time: 18.6762 sec.
# ステップ( 5620 )  loss: 3.8132 -- time: 18.3170 sec.
# ステップ( 5630 )  loss: 4.0419 -- time: 18.2402 sec.
# ステップ( 5640 )  loss: 4.1791 -- time: 18.3867 sec.
# ステップ( 5650 )  loss: 3.9989 -- time: 18.6740 sec.
# ステップ( 5660 )  loss: 3.9849 -- time: 18.3651 sec.
# ステップ( 5670 )  loss: 3.8103 -- time: 18.5712 sec.
# ステップ( 5680 )  loss: 4.0812 -- time: 18.6653 sec.
# ステップ( 5690 )  loss: 3.7723 -- time: 18.1550 sec.
# ステップ( 5700 )  loss: 4.0614 -- time: 18.4446 sec.
# ステップ( 5710 )  loss: 3.6776 -- time: 18.5476 sec.
# ステップ( 5720 )  loss: 3.9576 -- time: 18.1296 sec.
# ---------------------------------------
# train_loss: 700.8851 - val_loss(Every 10 epochs): 0.0000
# time:  343.5359 sec.
# ---------------------------------------
# Epoch 33/50
# ---------------------------------------
# ステップ( 5730 )  loss: 3.7183 -- time: 2.9746 sec.
# ステップ( 5740 )  loss: 3.8039 -- time: 18.3664 sec.
# ステップ( 5750 )  loss: 3.5754 -- time: 18.5715 sec.
# ステップ( 5760 )  loss: 4.0191 -- time: 18.2674 sec.
# ステップ( 5770 )  loss: 3.7985 -- time: 18.5745 sec.
# ステップ( 5780 )  loss: 3.8150 -- time: 18.2100 sec.
# ステップ( 5790 )  loss: 3.7652 -- time: 18.1969 sec.
# ステップ( 5800 )  loss: 3.6583 -- time: 18.2591 sec.
# ステップ( 5810 )  loss: 4.1868 -- time: 18.4323 sec.
# ステップ( 5820 )  loss: 4.5467 -- time: 18.2838 sec.
# ステップ( 5830 )  loss: 4.4233 -- time: 18.3426 sec.
# ステップ( 5840 )  loss: 4.0404 -- time: 18.4201 sec.
# ステップ( 5850 )  loss: 3.8538 -- time: 18.4552 sec.
# ステップ( 5860 )  loss: 3.7484 -- time: 18.5120 sec.
# ステップ( 5870 )  loss: 4.1092 -- time: 18.4272 sec.
# ステップ( 5880 )  loss: 4.0242 -- time: 18.1560 sec.
# ステップ( 5890 )  loss: 3.6374 -- time: 18.1622 sec.
# ステップ( 5900 )  loss: 3.7608 -- time: 18.2082 sec.
# ---------------------------------------
# train_loss: 692.7324 - val_loss(Every 10 epochs): 0.0000
# time:  342.3844 sec.
# ---------------------------------------
# Epoch 34/50
# ---------------------------------------
# ステップ( 5910 )  loss: 3.8548 -- time: 4.8509 sec.
# ステップ( 5920 )  loss: 4.1066 -- time: 18.3916 sec.
# ステップ( 5930 )  loss: 3.8236 -- time: 18.1076 sec.
# ステップ( 5940 )  loss: 4.1746 -- time: 18.4311 sec.
# ステップ( 5950 )  loss: 4.0308 -- time: 18.5734 sec.
# ステップ( 5960 )  loss: 3.3824 -- time: 18.0781 sec.
# ステップ( 5970 )  loss: 3.5000 -- time: 18.2669 sec.
# ステップ( 5980 )  loss: 3.4636 -- time: 18.1528 sec.
# ステップ( 5990 )  loss: 4.2605 -- time: 18.2074 sec.
# ステップ( 6000 )  loss: 3.7717 -- time: 18.2778 sec.
# ステップ( 6010 )  loss: 3.8296 -- time: 18.3620 sec.
# ステップ( 6020 )  loss: 3.6398 -- time: 18.4946 sec.
# ステップ( 6030 )  loss: 3.8468 -- time: 18.4745 sec.
# ステップ( 6040 )  loss: 3.9245 -- time: 18.5992 sec.
# ステップ( 6050 )  loss: 3.9040 -- time: 18.3338 sec.
# ステップ( 6060 )  loss: 3.8512 -- time: 18.5595 sec.
# ステップ( 6070 )  loss: 3.9667 -- time: 18.1152 sec.
# ステップ( 6080 )  loss: 3.6136 -- time: 18.2312 sec.
# ---------------------------------------
# train_loss: 689.2518 - val_loss(Every 10 epochs): 0.0000
# time:  342.2515 sec.
# ---------------------------------------
# Epoch 35/50
# ---------------------------------------
# ステップ( 6090 )  loss: 3.6846 -- time: 7.0500 sec.
# ステップ( 6100 )  loss: 3.8116 -- time: 18.1777 sec.
# ステップ( 6110 )  loss: 3.4837 -- time: 18.7352 sec.
# ステップ( 6120 )  loss: 4.0324 -- time: 18.0343 sec.
# ステップ( 6130 )  loss: 3.1969 -- time: 18.1402 sec.
# ステップ( 6140 )  loss: 4.0230 -- time: 18.2113 sec.
# ステップ( 6150 )  loss: 3.8366 -- time: 18.5459 sec.
# ステップ( 6160 )  loss: 3.9678 -- time: 18.3496 sec.
# ステップ( 6170 )  loss: 3.9604 -- time: 18.4339 sec.
# ステップ( 6180 )  loss: 4.0494 -- time: 18.3135 sec.
# ステップ( 6190 )  loss: 3.5570 -- time: 18.5711 sec.
# ステップ( 6200 )  loss: 3.5323 -- time: 18.5456 sec.
# ステップ( 6210 )  loss: 4.0442 -- time: 18.3462 sec.
# ステップ( 6220 )  loss: 3.5660 -- time: 18.4465 sec.
# ステップ( 6230 )  loss: 3.8036 -- time: 18.2714 sec.
# ステップ( 6240 )  loss: 4.0846 -- time: 18.2859 sec.
# ステップ( 6250 )  loss: 3.9179 -- time: 18.5174 sec.
# ステップ( 6260 )  loss: 3.6981 -- time: 18.2620 sec.
# ---------------------------------------
# train_loss: 687.4496 - val_loss(Every 10 epochs): 0.0000
# time:  343.0516 sec.
# ---------------------------------------
# Epoch 36/50
# ---------------------------------------
# ステップ( 6270 )  loss: 3.8725 -- time: 8.8802 sec.
# ステップ( 6280 )  loss: 3.2136 -- time: 18.1073 sec.
# ステップ( 6290 )  loss: 3.9755 -- time: 18.6711 sec.
# ステップ( 6300 )  loss: 4.0194 -- time: 18.3795 sec.
# ステップ( 6310 )  loss: 3.7298 -- time: 18.6189 sec.
# ステップ( 6320 )  loss: 3.1338 -- time: 18.0971 sec.
# ステップ( 6330 )  loss: 3.5216 -- time: 18.5414 sec.
# ステップ( 6340 )  loss: 3.7452 -- time: 18.4229 sec.
# ステップ( 6350 )  loss: 4.5360 -- time: 18.3722 sec.
# ステップ( 6360 )  loss: 4.0370 -- time: 18.6945 sec.
# ステップ( 6370 )  loss: 3.7898 -- time: 18.2625 sec.
# ステップ( 6380 )  loss: 3.6558 -- time: 18.2525 sec.
# ステップ( 6390 )  loss: 3.6823 -- time: 18.5527 sec.
# ステップ( 6400 )  loss: 3.5444 -- time: 18.2835 sec.
# ステップ( 6410 )  loss: 3.4916 -- time: 18.4509 sec.
# ステップ( 6420 )  loss: 3.9570 -- time: 18.5069 sec.
# ステップ( 6430 )  loss: 3.3484 -- time: 18.4003 sec.
# ステップ( 6440 )  loss: 3.4284 -- time: 18.2843 sec.
# ---------------------------------------
# train_loss: 676.0742 - val_loss(Every 10 epochs): 0.0000
# time:  343.7743 sec.
# ---------------------------------------
# Epoch 37/50
# ---------------------------------------
# ステップ( 6450 )  loss: 3.4809 -- time: 10.7293 sec.
# ステップ( 6460 )  loss: 3.2364 -- time: 18.4186 sec.
# ステップ( 6470 )  loss: 3.4656 -- time: 18.6833 sec.
# ステップ( 6480 )  loss: 3.9476 -- time: 18.2900 sec.
# ステップ( 6490 )  loss: 3.5747 -- time: 18.2349 sec.
# ステップ( 6500 )  loss: 3.4418 -- time: 18.3803 sec.
# ステップ( 6510 )  loss: 3.9779 -- time: 18.7154 sec.
# ステップ( 6520 )  loss: 4.0004 -- time: 18.1364 sec.
# ステップ( 6530 )  loss: 3.5094 -- time: 18.0947 sec.
# ステップ( 6540 )  loss: 3.4814 -- time: 18.4083 sec.
# ステップ( 6550 )  loss: 4.0262 -- time: 18.4200 sec.
# ステップ( 6560 )  loss: 4.1795 -- time: 18.4073 sec.
# ステップ( 6570 )  loss: 3.3246 -- time: 18.2409 sec.
# ステップ( 6580 )  loss: 3.5937 -- time: 18.4312 sec.
# ステップ( 6590 )  loss: 3.5157 -- time: 18.4470 sec.
# ステップ( 6600 )  loss: 4.2476 -- time: 18.6166 sec.
# ステップ( 6610 )  loss: 3.3482 -- time: 18.2248 sec.
# ステップ( 6620 )  loss: 4.2551 -- time: 18.5222 sec.
# ---------------------------------------
# train_loss: 673.4120 - val_loss(Every 10 epochs): 0.0000
# time:  343.2682 sec.
# ---------------------------------------
# Epoch 38/50
# ---------------------------------------
# ステップ( 6630 )  loss: 4.0422 -- time: 12.9852 sec.
# ステップ( 6640 )  loss: 3.6220 -- time: 18.4306 sec.
# ステップ( 6650 )  loss: 3.7706 -- time: 18.2839 sec.
# ステップ( 6660 )  loss: 3.8379 -- time: 18.1444 sec.
# ステップ( 6670 )  loss: 3.6361 -- time: 18.3606 sec.
# ステップ( 6680 )  loss: 3.3017 -- time: 18.4088 sec.
# ステップ( 6690 )  loss: 3.5970 -- time: 18.3876 sec.
# ステップ( 6700 )  loss: 3.5692 -- time: 18.3919 sec.
# ステップ( 6710 )  loss: 3.6609 -- time: 17.9923 sec.
# ステップ( 6720 )  loss: 3.9905 -- time: 18.4618 sec.
# ステップ( 6730 )  loss: 3.7650 -- time: 18.5791 sec.
# ステップ( 6740 )  loss: 3.9749 -- time: 18.4517 sec.
# ステップ( 6750 )  loss: 4.3089 -- time: 18.4089 sec.
# ステップ( 6760 )  loss: 3.8842 -- time: 18.4195 sec.
# ステップ( 6770 )  loss: 3.6723 -- time: 18.4558 sec.
# ステップ( 6780 )  loss: 3.2899 -- time: 18.1448 sec.
# ステップ( 6790 )  loss: 3.8581 -- time: 18.2937 sec.
# ステップ( 6800 )  loss: 3.7787 -- time: 18.4244 sec.
# ---------------------------------------
# train_loss: 668.5279 - val_loss(Every 10 epochs): 0.0000
# time:  342.9423 sec.
# ---------------------------------------
# Epoch 39/50
# ---------------------------------------
# ステップ( 6810 )  loss: 3.7778 -- time: 14.5303 sec.
# ステップ( 6820 )  loss: 3.1109 -- time: 18.3622 sec.
# ステップ( 6830 )  loss: 3.8956 -- time: 18.1152 sec.
# ステップ( 6840 )  loss: 3.4744 -- time: 18.7198 sec.
# ステップ( 6850 )  loss: 3.8728 -- time: 18.8574 sec.
# ステップ( 6860 )  loss: 3.7069 -- time: 18.4401 sec.
# ステップ( 6870 )  loss: 3.5406 -- time: 18.4708 sec.
# ステップ( 6880 )  loss: 3.5562 -- time: 18.2526 sec.
# ステップ( 6890 )  loss: 3.7045 -- time: 18.2951 sec.
# ステップ( 6900 )  loss: 3.5716 -- time: 18.0626 sec.
# ステップ( 6910 )  loss: 3.4209 -- time: 18.1221 sec.
# ステップ( 6920 )  loss: 3.3821 -- time: 18.3262 sec.
# ステップ( 6930 )  loss: 3.7056 -- time: 18.5215 sec.
# ステップ( 6940 )  loss: 3.4109 -- time: 18.6795 sec.
# ステップ( 6950 )  loss: 3.4947 -- time: 18.5621 sec.
# ステップ( 6960 )  loss: 3.5450 -- time: 18.3315 sec.
# ステップ( 6970 )  loss: 4.1090 -- time: 18.4044 sec.
# ステップ( 6980 )  loss: 3.7879 -- time: 18.3730 sec.
# ---------------------------------------
# train_loss: 660.5661 - val_loss(Every 10 epochs): 0.0000
# time:  343.4734 sec.
# ---------------------------------------
# Epoch 40/50
# ---------------------------------------
# ステップ( 6990 )  loss: 3.7364 -- time: 16.4447 sec.
# ステップ( 7000 )  loss: 3.7288 -- time: 18.5496 sec.
# ステップ( 7010 )  loss: 3.3598 -- time: 18.4078 sec.
# ステップ( 7020 )  loss: 3.8891 -- time: 18.2387 sec.
# ステップ( 7030 )  loss: 3.8663 -- time: 18.3742 sec.
# ステップ( 7040 )  loss: 4.0764 -- time: 18.4565 sec.
# ステップ( 7050 )  loss: 3.6949 -- time: 18.2331 sec.
# ステップ( 7060 )  loss: 3.6582 -- time: 18.3617 sec.
# ステップ( 7070 )  loss: 3.8912 -- time: 18.2515 sec.
# ステップ( 7080 )  loss: 3.4982 -- time: 18.3126 sec.
# ステップ( 7090 )  loss: 3.8275 -- time: 18.7391 sec.
# ステップ( 7100 )  loss: 4.2710 -- time: 18.7852 sec.
# ステップ( 7110 )  loss: 3.3199 -- time: 18.2334 sec.
# ステップ( 7120 )  loss: 3.6931 -- time: 18.3223 sec.
# ステップ( 7130 )  loss: 4.1031 -- time: 18.4507 sec.
# ステップ( 7140 )  loss: 3.8133 -- time: 18.4785 sec.
# ステップ( 7150 )  loss: 3.5523 -- time: 18.2531 sec.
# ステップ( 7160 )  loss: 3.1505 -- time: 18.0553 sec.
# ---------------------------------------
# （validation）
# ---------------------------------------
# train_loss: 662.3302 - val_loss(Every 10 epochs): 707.2897
# time:  484.9343 sec.
# --saved weights--
# ---------------------------------------
# Epoch 41/50
# ---------------------------------------
# ステップ( 7170 )  loss: 3.5758 -- time: 18.5849 sec.
# ステップ( 7180 )  loss: 3.8587 -- time: 18.5908 sec.
# ステップ( 7190 )  loss: 4.1601 -- time: 18.5169 sec.
# ステップ( 7200 )  loss: 3.1274 -- time: 18.7607 sec.
# ステップ( 7210 )  loss: 3.7267 -- time: 18.5129 sec.
# ステップ( 7220 )  loss: 4.0877 -- time: 18.5374 sec.
# ステップ( 7230 )  loss: 3.7565 -- time: 18.1412 sec.
# ステップ( 7240 )  loss: 3.5452 -- time: 18.3086 sec.
# ステップ( 7250 )  loss: 3.5780 -- time: 18.0585 sec.
# ステップ( 7260 )  loss: 3.6262 -- time: 18.7868 sec.
# ステップ( 7270 )  loss: 3.2822 -- time: 18.5005 sec.
# ステップ( 7280 )  loss: 3.7121 -- time: 18.3652 sec.
# ステップ( 7290 )  loss: 3.5446 -- time: 18.2680 sec.
# ステップ( 7300 )  loss: 3.7540 -- time: 18.1309 sec.
# ステップ( 7310 )  loss: 3.9820 -- time: 18.5057 sec.
# ステップ( 7320 )  loss: 3.3803 -- time: 18.6284 sec.
# ステップ( 7330 )  loss: 3.6530 -- time: 18.4327 sec.
# ---------------------------------------
# train_loss: 652.5686 - val_loss(Every 10 epochs): 0.0000
# time:  344.4224 sec.
# ---------------------------------------
# Epoch 42/50
# ---------------------------------------
# ステップ( 7340 )  loss: 3.5509 -- time: 1.1296 sec.
# ステップ( 7350 )  loss: 3.5415 -- time: 18.5461 sec.
# ステップ( 7360 )  loss: 3.0280 -- time: 18.4315 sec.
# ステップ( 7370 )  loss: 4.0839 -- time: 18.3581 sec.
# ステップ( 7380 )  loss: 4.0024 -- time: 18.3167 sec.
# ステップ( 7390 )  loss: 3.4167 -- time: 18.2214 sec.
# ステップ( 7400 )  loss: 3.5685 -- time: 18.6416 sec.
# ステップ( 7410 )  loss: 3.3844 -- time: 18.7791 sec.
# ステップ( 7420 )  loss: 3.9314 -- time: 18.2574 sec.
# ステップ( 7430 )  loss: 3.5933 -- time: 18.6390 sec.
# ステップ( 7440 )  loss: 3.9965 -- time: 18.3244 sec.
# ステップ( 7450 )  loss: 3.9858 -- time: 18.5876 sec.
# ステップ( 7460 )  loss: 2.9032 -- time: 18.5039 sec.
# ステップ( 7470 )  loss: 3.3528 -- time: 18.2922 sec.
# ステップ( 7480 )  loss: 3.1977 -- time: 18.3823 sec.
# ステップ( 7490 )  loss: 4.1735 -- time: 18.4936 sec.
# ステップ( 7500 )  loss: 3.7460 -- time: 18.1296 sec.
# ステップ( 7510 )  loss: 3.4363 -- time: 18.5478 sec.
# ---------------------------------------
# train_loss: 642.8596 - val_loss(Every 10 epochs): 0.0000
# time:  344.0666 sec.
# ---------------------------------------
# Epoch 43/50
# ---------------------------------------
# ステップ( 7520 )  loss: 3.2603 -- time: 3.0617 sec.
# ステップ( 7530 )  loss: 3.4094 -- time: 18.5171 sec.
# ステップ( 7540 )  loss: 3.6083 -- time: 18.4877 sec.
# ステップ( 7550 )  loss: 3.3504 -- time: 18.2247 sec.
# ステップ( 7560 )  loss: 3.4348 -- time: 18.3840 sec.
# ステップ( 7570 )  loss: 3.4838 -- time: 18.2440 sec.
# ステップ( 7580 )  loss: 3.7025 -- time: 18.2325 sec.
# ステップ( 7590 )  loss: 3.0456 -- time: 18.3555 sec.
# ステップ( 7600 )  loss: 3.2895 -- time: 18.6048 sec.
# ステップ( 7610 )  loss: 3.9318 -- time: 18.5152 sec.
# ステップ( 7620 )  loss: 3.4988 -- time: 18.5954 sec.
# ステップ( 7630 )  loss: 3.4571 -- time: 18.2395 sec.
# ステップ( 7640 )  loss: 3.4136 -- time: 18.5569 sec.
# ステップ( 7650 )  loss: 3.3573 -- time: 18.4936 sec.
# ステップ( 7660 )  loss: 3.2719 -- time: 18.4195 sec.
# ステップ( 7670 )  loss: 3.5673 -- time: 18.2639 sec.
# ステップ( 7680 )  loss: 2.9754 -- time: 18.4753 sec.
# ステップ( 7690 )  loss: 3.3428 -- time: 18.3780 sec.
# ---------------------------------------
# train_loss: 641.6548 - val_loss(Every 10 epochs): 0.0000
# time:  343.7302 sec.
# ---------------------------------------
# Epoch 44/50
# ---------------------------------------
# ステップ( 7700 )  loss: 3.1822 -- time: 4.9118 sec.
# ステップ( 7710 )  loss: 3.7489 -- time: 18.5192 sec.
# ステップ( 7720 )  loss: 3.9704 -- time: 18.6379 sec.
# ステップ( 7730 )  loss: 3.0379 -- time: 18.6849 sec.
# ステップ( 7740 )  loss: 3.8917 -- time: 18.5242 sec.
# ステップ( 7750 )  loss: 4.2060 -- time: 18.3996 sec.
# ステップ( 7760 )  loss: 3.4188 -- time: 18.2020 sec.
# ステップ( 7770 )  loss: 3.3078 -- time: 18.3349 sec.
# ステップ( 7780 )  loss: 3.4287 -- time: 18.5726 sec.
# ステップ( 7790 )  loss: 3.7474 -- time: 18.4154 sec.
# ステップ( 7800 )  loss: 3.6444 -- time: 18.1727 sec.
# ステップ( 7810 )  loss: 3.7333 -- time: 18.6193 sec.
# ステップ( 7820 )  loss: 3.8168 -- time: 18.2836 sec.
# ステップ( 7830 )  loss: 3.8867 -- time: 18.6965 sec.
# ステップ( 7840 )  loss: 4.0584 -- time: 18.5241 sec.
# ステップ( 7850 )  loss: 3.1778 -- time: 18.2355 sec.
# ステップ( 7860 )  loss: 3.9712 -- time: 18.4467 sec.
# ステップ( 7870 )  loss: 3.7778 -- time: 18.6542 sec.
# ---------------------------------------
# train_loss: 638.8515 - val_loss(Every 10 epochs): 0.0000
# time:  344.4225 sec.
# ---------------------------------------
# Epoch 45/50
# ---------------------------------------
# ステップ( 7880 )  loss: 3.4813 -- time: 6.8221 sec.
# ステップ( 7890 )  loss: 3.7822 -- time: 18.5180 sec.
# ステップ( 7900 )  loss: 3.4838 -- time: 18.4944 sec.
# ステップ( 7910 )  loss: 3.3250 -- time: 18.4269 sec.
# ステップ( 7920 )  loss: 3.0532 -- time: 18.4038 sec.
# ステップ( 7930 )  loss: 3.5691 -- time: 18.1193 sec.
# ステップ( 7940 )  loss: 3.7137 -- time: 18.3324 sec.
# ステップ( 7950 )  loss: 3.6564 -- time: 18.3508 sec.
# ステップ( 7960 )  loss: 3.3831 -- time: 18.2955 sec.
# ステップ( 7970 )  loss: 3.6187 -- time: 18.5358 sec.
# ステップ( 7980 )  loss: 3.4735 -- time: 18.2796 sec.
# ステップ( 7990 )  loss: 3.8963 -- time: 18.5888 sec.
# ステップ( 8000 )  loss: 3.8710 -- time: 18.6341 sec.
# ステップ( 8010 )  loss: 3.9619 -- time: 18.4295 sec.
# ステップ( 8020 )  loss: 3.8921 -- time: 18.3788 sec.
# ステップ( 8030 )  loss: 3.3488 -- time: 18.5492 sec.
# ステップ( 8040 )  loss: 3.0960 -- time: 18.6895 sec.
# ステップ( 8050 )  loss: 3.2303 -- time: 18.3288 sec.
# ---------------------------------------
# train_loss: 632.4864 - val_loss(Every 10 epochs): 0.0000
# time:  343.8795 sec.
# ---------------------------------------
# Epoch 46/50
# ---------------------------------------
# ステップ( 8060 )  loss: 3.5082 -- time: 8.8979 sec.
# ステップ( 8070 )  loss: 3.6844 -- time: 18.4731 sec.
# ステップ( 8080 )  loss: 3.3037 -- time: 18.2408 sec.
# ステップ( 8090 )  loss: 3.5794 -- time: 18.4389 sec.
# ステップ( 8100 )  loss: 3.8734 -- time: 18.6275 sec.
# ステップ( 8110 )  loss: 3.8396 -- time: 18.4291 sec.
# ステップ( 8120 )  loss: 3.9809 -- time: 18.3520 sec.
# ステップ( 8130 )  loss: 3.0621 -- time: 18.4569 sec.
# ステップ( 8140 )  loss: 3.0035 -- time: 18.6187 sec.
# ステップ( 8150 )  loss: 3.6268 -- time: 18.7690 sec.
# ステップ( 8160 )  loss: 3.5678 -- time: 18.6795 sec.
# ステップ( 8170 )  loss: 3.7787 -- time: 18.3420 sec.
# ステップ( 8180 )  loss: 3.6048 -- time: 18.3894 sec.
# ステップ( 8190 )  loss: 3.5630 -- time: 18.6225 sec.
# ステップ( 8200 )  loss: 4.2624 -- time: 18.3508 sec.
# ステップ( 8210 )  loss: 3.7275 -- time: 18.6317 sec.
# ステップ( 8220 )  loss: 3.6741 -- time: 18.2925 sec.
# ステップ( 8230 )  loss: 3.2597 -- time: 18.2764 sec.
# ---------------------------------------
# train_loss: 628.2521 - val_loss(Every 10 epochs): 0.0000
# time:  344.7451 sec.
# ---------------------------------------
# Epoch 47/50
# ---------------------------------------
# ステップ( 8240 )  loss: 3.2324 -- time: 10.6414 sec.
# ステップ( 8250 )  loss: 3.5780 -- time: 18.2011 sec.
# ステップ( 8260 )  loss: 3.8013 -- time: 18.4871 sec.
# ステップ( 8270 )  loss: 3.4000 -- time: 18.5371 sec.
# ステップ( 8280 )  loss: 3.2394 -- time: 18.2000 sec.
# ステップ( 8290 )  loss: 3.5543 -- time: 18.4189 sec.
# ステップ( 8300 )  loss: 3.5143 -- time: 18.6248 sec.
# ステップ( 8310 )  loss: 3.6260 -- time: 18.3761 sec.
# ステップ( 8320 )  loss: 3.9965 -- time: 18.7202 sec.
# ステップ( 8330 )  loss: 3.3807 -- time: 18.3121 sec.
# ステップ( 8340 )  loss: 3.3419 -- time: 18.7675 sec.
# ステップ( 8350 )  loss: 3.9669 -- time: 18.3316 sec.
# ステップ( 8360 )  loss: 4.0118 -- time: 18.1564 sec.
# ステップ( 8370 )  loss: 3.8269 -- time: 18.0965 sec.
# ステップ( 8380 )  loss: 3.1989 -- time: 18.5653 sec.
# ステップ( 8390 )  loss: 2.9707 -- time: 18.1286 sec.
# ステップ( 8400 )  loss: 4.1046 -- time: 18.2802 sec.
# ステップ( 8410 )  loss: 3.5758 -- time: 18.3135 sec.
# ---------------------------------------
# train_loss: 623.3777 - val_loss(Every 10 epochs): 0.0000
# time:  343.0071 sec.
# ---------------------------------------
# Epoch 48/50
# ---------------------------------------
# ステップ( 8420 )  loss: 3.8771 -- time: 12.7963 sec.
# ステップ( 8430 )  loss: 3.6520 -- time: 18.5351 sec.
# ステップ( 8440 )  loss: 3.4922 -- time: 18.3364 sec.
# ステップ( 8450 )  loss: 4.0222 -- time: 18.5432 sec.
# ステップ( 8460 )  loss: 3.4137 -- time: 18.3865 sec.
# ステップ( 8470 )  loss: 3.4422 -- time: 18.4666 sec.
# ステップ( 8480 )  loss: 3.3398 -- time: 18.5926 sec.
# ステップ( 8490 )  loss: 3.5718 -- time: 18.3827 sec.
# ステップ( 8500 )  loss: 3.7161 -- time: 18.2812 sec.
# ステップ( 8510 )  loss: 3.3276 -- time: 18.3952 sec.
# ステップ( 8520 )  loss: 3.6530 -- time: 18.4104 sec.
# ステップ( 8530 )  loss: 2.8487 -- time: 18.5529 sec.
# ステップ( 8540 )  loss: 3.0916 -- time: 18.4956 sec.
# ステップ( 8550 )  loss: 3.6993 -- time: 18.3778 sec.
# ステップ( 8560 )  loss: 3.5773 -- time: 18.1917 sec.
# ステップ( 8570 )  loss: 3.8078 -- time: 18.6097 sec.
# ステップ( 8580 )  loss: 3.5177 -- time: 18.4430 sec.
# ステップ( 8590 )  loss: 3.2968 -- time: 18.3622 sec.
# ---------------------------------------
# train_loss: 623.5234 - val_loss(Every 10 epochs): 0.0000
# time:  344.0970 sec.
# ---------------------------------------
# Epoch 49/50
# ---------------------------------------
# ステップ( 8600 )  loss: 3.0549 -- time: 14.7997 sec.
# ステップ( 8610 )  loss: 3.3862 -- time: 18.3559 sec.
# ステップ( 8620 )  loss: 3.5659 -- time: 18.6129 sec.
# ステップ( 8630 )  loss: 3.5449 -- time: 18.6437 sec.
# ステップ( 8640 )  loss: 3.3704 -- time: 18.3777 sec.
# ステップ( 8650 )  loss: 3.2321 -- time: 18.3949 sec.
# ステップ( 8660 )  loss: 2.8192 -- time: 18.5180 sec.
# ステップ( 8670 )  loss: 2.8808 -- time: 18.3385 sec.
# ステップ( 8680 )  loss: 3.5902 -- time: 18.2691 sec.
# ステップ( 8690 )  loss: 3.4560 -- time: 18.1633 sec.
# ステップ( 8700 )  loss: 4.0169 -- time: 18.7809 sec.
# ステップ( 8710 )  loss: 3.3659 -- time: 18.4398 sec.
# ステップ( 8720 )  loss: 3.1167 -- time: 18.4088 sec.
# ステップ( 8730 )  loss: 3.6346 -- time: 18.3216 sec.
# ステップ( 8740 )  loss: 3.1772 -- time: 18.1874 sec.
# ステップ( 8750 )  loss: 3.7922 -- time: 18.5981 sec.
# ステップ( 8760 )  loss: 3.6533 -- time: 18.4289 sec.
# ステップ( 8770 )  loss: 3.5111 -- time: 18.5764 sec.
# ---------------------------------------
# train_loss: 620.1383 - val_loss(Every 10 epochs): 0.0000
# time:  344.2814 sec.
# ---------------------------------------
# Epoch 50/50
# ---------------------------------------
# ステップ( 8780 )  loss: 3.1639 -- time: 16.6422 sec.
# ステップ( 8790 )  loss: 3.5662 -- time: 18.4837 sec.
# ステップ( 8800 )  loss: 3.9478 -- time: 18.3289 sec.
# ステップ( 8810 )  loss: 3.1863 -- time: 18.4424 sec.
# ステップ( 8820 )  loss: 3.6648 -- time: 18.5958 sec.
# ステップ( 8830 )  loss: 3.4711 -- time: 18.4605 sec.
# ステップ( 8840 )  loss: 3.6759 -- time: 18.5925 sec.
# ステップ( 8850 )  loss: 3.1865 -- time: 18.1364 sec.
# ステップ( 8860 )  loss: 3.6605 -- time: 18.6130 sec.
# ステップ( 8870 )  loss: 3.5219 -- time: 18.4609 sec.
# ステップ( 8880 )  loss: 3.2808 -- time: 18.5752 sec.
# ステップ( 8890 )  loss: 3.6096 -- time: 18.1818 sec.
# ステップ( 8900 )  loss: 3.4602 -- time: 18.0891 sec.
# ステップ( 8910 )  loss: 3.1258 -- time: 18.2262 sec.
# ステップ( 8920 )  loss: 3.4124 -- time: 18.3622 sec.
# ステップ( 8930 )  loss: 3.2753 -- time: 18.6861 sec.
# ステップ( 8940 )  loss: 3.1266 -- time: 18.3439 sec.
# ステップ( 8950 )  loss: 3.1333 -- time: 18.0883 sec.
# ---------------------------------------
# （validation）
# ---------------------------------------
# train_loss: 619.2510 - val_loss(Every 10 epochs): 697.8000
# time:  487.1431 sec.
# --saved weights--
# CPU times: user 4h 48min 42s, sys: 4min 54s, total: 4h 53min 37s
# Wall time: 6h 17min 40s
